# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/Telecom_customer_churn.csv")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# 1             Yes                No             DSL            Yes  ...
# 2             Yes                No             DSL            Yes  ...
# 3              No  No phone service             DSL            Yes  ...
# 4             Yes                No     Fiber optic             No  ...
# ...           ...               ...             ...            ...  ...
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0                  No          No          No              No  Month-to-month
# 1                 Yes          No          No              No        One year
# 2                  No          No          No              No  Month-to-month
# 3                 Yes         Yes          No              No        One year
# 4                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7038              Yes         Yes         Yes             Yes        One year
# 7039              Yes          No         Yes             Yes        One year
# 7040               No          No          No              No  Month-to-month
# 7041               No          No          No              No  Month-to-month
# 7042              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# 0                 Yes           Electronic check          29.85         29.85
# 1                  No               Mailed check          56.95        1889.5
# 2                 Yes               Mailed check          53.85        108.15
# 3                  No  Bank transfer (automatic)          42.30       1840.75
# 4                 Yes           Electronic check          70.70        151.65
# ...               ...                        ...            ...           ...
# 7038              Yes               Mailed check          84.80        1990.5
# 7039              Yes    Credit card (automatic)         103.20        7362.9
# 7040              Yes           Electronic check          29.60        346.45
# 7041              Yes               Mailed check          74.40         306.6
# 7042              Yes  Bank transfer (automatic)         105.65        6844.5
#
#      Churn
# 0       No
# 1       No
# 2      Yes
# 3       No
# 4      Yes
# ...    ...
# 7038    No
# 7039    No
# 7040    No
# 7041   Yes
# 7042    No
#
# [7043 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.isna().all()
# Out:
# customerID          False
# gender              False
# SeniorCitizen       False
# Partner             False
# Dependents          False
# tenure              False
# PhoneService        False
# MultipleLines       False
# InternetService     False
# OnlineSecurity      False
# OnlineBackup        False
# DeviceProtection    False
# TechSupport         False
# StreamingTV         False
# StreamingMovies     False
# Contract            False
# PaperlessBilling    False
# PaymentMethod       False
# MonthlyCharges      False
# TotalCharges        False
# Churn               False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#heatmap for null values 
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %%
#transforming the data

from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        print(i)
        df[i]=le.fit_transform(df[i])
# Out:
# customerID
# gender
# Partner
# Dependents
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# TotalCharges
# Churn

# %%
df.corr()
# Out:
#                   customerID    gender  SeniorCitizen   Partner  Dependents  \
# customerID          1.000000  0.006288      -0.002074 -0.026729   -0.012823
# gender              0.006288  1.000000      -0.001874 -0.001808    0.010517
# SeniorCitizen      -0.002074 -0.001874       1.000000  0.016479   -0.211185
# Partner            -0.026729 -0.001808       0.016479  1.000000    0.452676
# Dependents         -0.012823  0.010517      -0.211185  0.452676    1.000000
# tenure              0.008035  0.005106       0.016567  0.379697    0.159712
# PhoneService       -0.006483 -0.006488       0.008576  0.017706   -0.001762
# MultipleLines       0.004316 -0.006739       0.146185  0.142410   -0.024991
# InternetService    -0.012407 -0.000863      -0.032310  0.000891    0.044590
# OnlineSecurity      0.013292 -0.015017      -0.128221  0.150828    0.152166
# OnlineBackup       -0.003334 -0.012057      -0.013632  0.153130    0.091015
# DeviceProtection   -0.006918  0.000549      -0.021398  0.166330    0.080537
# TechSupport         0.001140 -0.006825      -0.151268  0.126733    0.133524
# StreamingTV        -0.007777 -0.006421       0.030776  0.137341    0.046885
# StreamingMovies    -0.016746 -0.008743       0.047266  0.129574    0.021321
# Contract            0.015028  0.000126      -0.142554  0.294806    0.243187
# PaperlessBilling   -0.001945 -0.011754       0.156530 -0.014877   -0.111377
# PaymentMethod       0.011604  0.017352      -0.038551 -0.154798   -0.040292
# MonthlyCharges     -0.003916 -0.014569       0.220173  0.096848   -0.113890
# TotalCharges        0.003027 -0.005291       0.037653  0.059568   -0.009572
# Churn              -0.017447 -0.008612       0.150889 -0.150448   -0.164221
#
#                     tenure  PhoneService  MultipleLines  InternetService  \
# customerID        0.008035     -0.006483       0.004316        -0.012407
# gender            0.005106     -0.006488      -0.006739        -0.000863
# SeniorCitizen     0.016567      0.008576       0.146185        -0.032310
# Partner           0.379697      0.017706       0.142410         0.000891
# Dependents        0.159712     -0.001762      -0.024991         0.044590
# tenure            1.000000      0.008448       0.343032        -0.030359
# PhoneService      0.008448      1.000000      -0.020538         0.387436
# MultipleLines     0.343032     -0.020538       1.000000        -0.109216
# InternetService  -0.030359      0.387436      -0.109216         1.000000
# OnlineSecurity    0.325468     -0.015198       0.007141        -0.028416
# OnlineBackup      0.370876      0.024105       0.117327         0.036138
# DeviceProtection  0.371105      0.003727       0.122318         0.044944
# TechSupport       0.322942     -0.019158       0.011466        -0.026047
# StreamingTV       0.289373      0.055353       0.175059         0.107417
# StreamingMovies   0.296866      0.043870       0.180957         0.098350
# Contract          0.671607      0.002247       0.110842         0.099721
# PaperlessBilling  0.006152      0.016505       0.165146        -0.138625
# PaymentMethod    -0.370436     -0.004184      -0.176793         0.086140
# MonthlyCharges    0.247900      0.247398       0.433576        -0.323260
# TotalCharges      0.158523      0.083195       0.114955        -0.055724
# Churn            -0.352229      0.011942       0.038037        -0.047291
#
#                   OnlineSecurity  ...  DeviceProtection  TechSupport  \
# customerID              0.013292  ...         -0.006918     0.001140
# gender                 -0.015017  ...          0.000549    -0.006825
# SeniorCitizen          -0.128221  ...         -0.021398    -0.151268
# Partner                 0.150828  ...          0.166330     0.126733
# Dependents              0.152166  ...          0.080537     0.133524
# tenure                  0.325468  ...          0.371105     0.322942
# PhoneService           -0.015198  ...          0.003727    -0.019158
# MultipleLines           0.007141  ...          0.122318     0.011466
# InternetService        -0.028416  ...          0.044944    -0.026047
# OnlineSecurity          1.000000  ...          0.175985     0.285028
# OnlineBackup            0.185126  ...          0.187757     0.195748
# DeviceProtection        0.175985  ...          1.000000     0.240593
# TechSupport             0.285028  ...          0.240593     1.000000
# StreamingTV             0.044669  ...          0.276652     0.161305
# StreamingMovies         0.055954  ...          0.288799     0.161316
# Contract                0.374416  ...          0.350277     0.425367
# PaperlessBilling       -0.157641  ...         -0.038234    -0.113600
# PaymentMethod          -0.096726  ...         -0.135750    -0.104670
# MonthlyCharges         -0.053878  ...          0.163652    -0.008682
# TotalCharges            0.042357  ...          0.105905     0.057488
# Churn                  -0.289309  ...         -0.178134    -0.282492
#
#                   StreamingTV  StreamingMovies  Contract  PaperlessBilling  \
# customerID          -0.007777        -0.016746  0.015028         -0.001945
# gender              -0.006421        -0.008743  0.000126         -0.011754
# SeniorCitizen        0.030776         0.047266 -0.142554          0.156530
# Partner              0.137341         0.129574  0.294806         -0.014877
# Dependents           0.046885         0.021321  0.243187         -0.111377
# tenure               0.289373         0.296866  0.671607          0.006152
# PhoneService         0.055353         0.043870  0.002247          0.016505
# MultipleLines        0.175059         0.180957  0.110842          0.165146
# InternetService      0.107417         0.098350  0.099721         -0.138625
# OnlineSecurity       0.044669         0.055954  0.374416         -0.157641
# OnlineBackup         0.147186         0.136722  0.280980         -0.013370
# DeviceProtection     0.276652         0.288799  0.350277         -0.038234
# TechSupport          0.161305         0.161316  0.425367         -0.113600
# StreamingTV          1.000000         0.434772  0.227116          0.096642
# StreamingMovies      0.434772         1.000000  0.231226          0.083700
# Contract             0.227116         0.231226  1.000000         -0.176733
# PaperlessBilling     0.096642         0.083700 -0.176733          1.000000
# PaymentMethod       -0.104234        -0.111241 -0.227543         -0.062904
# MonthlyCharges       0.336706         0.335459 -0.074195          0.352150
# TotalCharges         0.138173         0.145366  0.106178          0.100957
# Churn               -0.036581        -0.038492 -0.396713          0.191825
#
#                   PaymentMethod  MonthlyCharges  TotalCharges     Churn
# customerID             0.011604       -0.003916      0.003027 -0.017447
# gender                 0.017352       -0.014569     -0.005291 -0.008612
# SeniorCitizen         -0.038551        0.220173      0.037653  0.150889
# Partner               -0.154798        0.096848      0.059568 -0.150448
# Dependents            -0.040292       -0.113890     -0.009572 -0.164221
# tenure                -0.370436        0.247900      0.158523 -0.352229
# PhoneService          -0.004184        0.247398      0.083195  0.011942
# MultipleLines         -0.176793        0.433576      0.114955  0.038037
# InternetService        0.086140       -0.323260     -0.055724 -0.047291
# OnlineSecurity        -0.096726       -0.053878      0.042357 -0.289309
# OnlineBackup          -0.124847        0.119777      0.090756 -0.195525
# DeviceProtection      -0.135750        0.163652      0.105905 -0.178134
# TechSupport           -0.104670       -0.008682      0.057488 -0.282492
# StreamingTV           -0.104234        0.336706      0.138173 -0.036581
# StreamingMovies       -0.111241        0.335459      0.145366 -0.038492
# Contract              -0.227543       -0.074195      0.106178 -0.396713
# PaperlessBilling      -0.062904        0.352150      0.100957  0.191825
# PaymentMethod          1.000000       -0.193407     -0.067477  0.107062
# MonthlyCharges        -0.193407        1.000000      0.279875  0.193356
# TotalCharges          -0.067477        0.279875      1.000000  0.014479
# Churn                  0.107062        0.193356      0.014479  1.000000
#
# [21 rows x 21 columns]

# %%
#correlation heatmap
plt.figure(figsize=(22,15))
sns.heatmap(df.corr(), annot=True,fmt="0.2f",linewidth=0.1,linecolor="black")
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# customerID          0.000000
# gender             -0.019031
# SeniorCitizen       1.833633
# Partner             0.067922
# Dependents          0.875199
# tenure              0.239540
# PhoneService       -2.727153
# MultipleLines       0.118719
# InternetService     0.205423
# OnlineSecurity      0.416985
# OnlineBackup        0.182930
# DeviceProtection    0.186847
# TechSupport         0.402365
# StreamingTV         0.028486
# StreamingMovies     0.014657
# Contract            0.630959
# PaperlessBilling   -0.375396
# PaymentMethod      -0.170129
# MonthlyCharges     -0.220524
# TotalCharges        0.015857
# Churn               1.063031
# dtype: float64

# %%
#checking for outliers 
import warnings
warnings.filterwarnings('ignore')

#checking for outliers
plt.figure(figsize=(20,10))
for o in enumerate(df):
    plt.subplot(9,5,o[0]+1)
    sns.boxplot(df[o[1]])

# %%
#dealing with outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
print(np.where(z>3))
# Out:
# (array([   0,    3,    7,   20,   27,   62,   81,   89,  103,  105,  107,
#         114,  116,  129,  131,  133,  168,  180,  185,  187,  206,  211,
#         215,  216,  217,  225,  236,  252,  255,  259,  260,  263,  272,
#         278,  303,  321,  324,  328,  348,  354,  358,  372,  376,  382,
#         387,  398,  424,  431,  435,  452,  465,  481,  488,  495,  498,
#         544,  569,  596,  610,  616,  620,  634,  660,  667,  669,  674,
#         677,  688,  716,  718,  735,  765,  776,  784,  790,  794,  813,
#         829,  843,  847,  859,  866,  873,  875,  877,  884,  893,  917,
#         934,  941,  943,  960,  973, 1011, 1018, 1037, 1050, 1051, 1053,
#        1072, 1110, 1119, 1122, 1144, 1146, 1150, 1161, 1169, 1182, 1204,
#        1221, 1225, 1242, 1255, 1257, 1271, 1278, 1298, 1311, 1326, 1331,
#        1333, 1334, 1340, 1349, 1352, 1365, 1379, 1402, 1407, 1416, 1452,
#        1479, 1480, 1481, 1500, 1506, 1513, 1519, 1560, 1562, 1581, 1584,
#        1614, 1620, 1634, 1637, 1652, 1689, 1692, 1694, 1703, 1722, 1734,
#        1789, 1802, 1803, 1819, 1827, 1832, 1845, 1851, 1854, 1862, 1881,
#        1889, 1892, 1894, 1906, 1910, 1944, 1959, 1969, 1985, 1989, 1998,
#        2002, 2031, 2046, 2050, 2087, 2089, 2090, 2117, 2124, 2127, 2131,
#        2188, 2215, 2225, 2226, 2237, 2239, 2290, 2295, 2310, 2340, 2344,
#        2348, 2362, 2382, 2383, 2385, 2398, 2399, 2409, 2412, 2413, 2417,
#        2420, 2421, 2426, 2427, 2431, 2433, 2465, 2468, 2492, 2533, 2538,
#        2541, 2547, 2562, 2608, 2610, 2626, 2637, 2644, 2661, 2662, 2681,
#        2696, 2700, 2709, 2712, 2718, 2725, 2728, 2748, 2751, 2752, 2754,
#        2761, 2773, 2781, 2804, 2809, 2814, 2841, 2842, 2889, 2898, 2899,
#        2903, 2913, 2915, 2916, 2918, 2919, 2929, 2940, 2944, 2962, 2966,
#        2972, 2990, 2992, 2994, 2995, 3020, 3028, 3036, 3039, 3042, 3043,
#        3060, 3062, 3070, 3073, 3080, 3092, 3096, 3126, 3127, 3133, 3139,
#        3150, 3160, 3174, 3177, 3183, 3185, 3190, 3191, 3194, 3213, 3221,
#        3223, 3233, 3235, 3243, 3258, 3290, 3292, 3311, 3316, 3318, 3342,
#        3354, 3363, 3370, 3414, 3422, 3444, 3454, 3492, 3502, 3505, 3541,
#        3542, 3557, 3575, 3583, 3586, 3594, 3613, 3614, 3617, 3620, 3621,
#        3652, 3653, 3660, 3677, 3680, 3685, 3690, 3722, 3733, 3738, 3753,
#        3756, 3773, 3819, 3860, 3870, 3873, 3877, 3902, 3905, 3926, 3934,
#        3940, 3945, 3946, 3955, 3961, 3973, 3976, 3983, 3989, 4008, 4020,
#        4024, 4027, 4029, 4040, 4041, 4043, 4048, 4052, 4054, 4055, 4056,
#        4071, 4075, 4085, 4099, 4109, 4128, 4130, 4132, 4141, 4149, 4151,
#        4162, 4168, 4174, 4178, 4180, 4183, 4200, 4207, 4208, 4233, 4239,
#        4251, 4281, 4290, 4309, 4310, 4311, 4338, 4369, 4396, 4400, 4402,
#        4409, 4411, 4424, 4432, 4465, 4474, 4481, 4521, 4537, 4557, 4565,
#        4603, 4612, 4641, 4653, 4657, 4665, 4670, 4702, 4710, 4726, 4728,
#        4729, 4740, 4750, 4765, 4773, 4821, 4828, 4831, 4840, 4845, 4849,
#        4854, 4857, 4860, 4882, 4883, 4897, 4898, 4915, 4919, 4924, 4933,
#        4949, 4965, 4968, 4970, 4974, 4976, 4981, 4983, 4989, 4992, 4993,
#        5002, 5013, 5014, 5017, 5034, 5060, 5062, 5064, 5066, 5073, 5085,
#        5091, 5117, 5130, 5144, 5147, 5163, 5176, 5180, 5186, 5204, 5207,
#        5210, 5212, 5216, 5249, 5263, 5264, 5284, 5290, 5292, 5296, 5303,
#        5314, 5329, 5331, 5338, 5343, 5348, 5356, 5359, 5382, 5387, 5391,
#        5392, 5411, 5456, 5489, 5497, 5501, 5505, 5531, 5536, 5546, 5559,
#        5565, 5601, 5607, 5631, 5636, 5648, 5665, 5666, 5674, 5682, 5683,
#        5690, 5717, 5740, 5761, 5788, 5790, 5796, 5799, 5829, 5833, 5837,
#        5841, 5880, 5884, 5889, 5891, 5900, 5911, 5939, 5941, 5942, 5949,
#        5950, 5954, 5961, 5967, 5976, 5983, 6001, 6006, 6007, 6020, 6030,
#        6031, 6039, 6043, 6059, 6064, 6067, 6074, 6080, 6087, 6093, 6108,
#        6129, 6132, 6133, 6145, 6149, 6162, 6174, 6183, 6204, 6209, 6212,
#        6218, 6219, 6220, 6235, 6248, 6252, 6253, 6256, 6260, 6263, 6269,
#        6285, 6296, 6310, 6319, 6326, 6331, 6367, 6377, 6383, 6392, 6406,
#        6415, 6416, 6424, 6425, 6435, 6455, 6457, 6459, 6493, 6494, 6500,
#        6503, 6509, 6514, 6515, 6522, 6523, 6530, 6536, 6547, 6553, 6570,
#        6573, 6593, 6600, 6607, 6624, 6640, 6653, 6661, 6662, 6665, 6677,
#        6679, 6683, 6684, 6691, 6693, 6703, 6727, 6747, 6750, 6752, 6757,
#        6777, 6779, 6783, 6791, 6810, 6811, 6813, 6834, 6864, 6881, 6884,
#        6891, 6895, 6904, 6905, 6937, 6940, 6941, 6943, 6946, 6949, 6964,
#        6966, 6979, 6980, 6984, 6985, 6999, 7003, 7007, 7029, 7036, 7040],
#       dtype=int64), array([6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6,
#        6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6, 6],
#       dtype=int64))

# %%
z=np.abs(zscore(df))
z.all()
# Out:
# customerID          False
# gender               True
# SeniorCitizen        True
# Partner              True
# Dependents           True
# tenure               True
# PhoneService         True
# MultipleLines        True
# InternetService      True
# OnlineSecurity       True
# OnlineBackup         True
# DeviceProtection     True
# TechSupport          True
# StreamingTV          True
# StreamingMovies      True
# Contract             True
# PaperlessBilling     True
# PaymentMethod        True
# MonthlyCharges       True
# TotalCharges         True
# Churn                True
# dtype: bool

# %%
df.nunique()
# Out:
# customerID          7043
# gender                 2
# SeniorCitizen          2
# Partner                2
# Dependents             2
# tenure                73
# PhoneService           2
# MultipleLines          3
# InternetService        3
# OnlineSecurity         3
# OnlineBackup           3
# DeviceProtection       3
# TechSupport            3
# StreamingTV            3
# StreamingMovies        3
# Contract               3
# PaperlessBilling       2
# PaymentMethod          4
# MonthlyCharges      1585
# TotalCharges        6531
# Churn                  2
# dtype: int64

# %%
df.hist(grid=False,figsize=(20,15),bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'customerID'}>,
#         <AxesSubplot:title={'center':'gender'}>,
#         <AxesSubplot:title={'center':'SeniorCitizen'}>,
#         <AxesSubplot:title={'center':'Partner'}>,
#         <AxesSubplot:title={'center':'Dependents'}>],
#        [<AxesSubplot:title={'center':'tenure'}>,
#         <AxesSubplot:title={'center':'PhoneService'}>,
#         <AxesSubplot:title={'center':'MultipleLines'}>,
#         <AxesSubplot:title={'center':'InternetService'}>,
#         <AxesSubplot:title={'center':'OnlineSecurity'}>],
#        [<AxesSubplot:title={'center':'OnlineBackup'}>,
#         <AxesSubplot:title={'center':'DeviceProtection'}>,
#         <AxesSubplot:title={'center':'TechSupport'}>,
#         <AxesSubplot:title={'center':'StreamingTV'}>,
#         <AxesSubplot:title={'center':'StreamingMovies'}>],
#        [<AxesSubplot:title={'center':'Contract'}>,
#         <AxesSubplot:title={'center':'PaperlessBilling'}>,
#         <AxesSubplot:title={'center':'PaymentMethod'}>,
#         <AxesSubplot:title={'center':'MonthlyCharges'}>,
#         <AxesSubplot:title={'center':'TotalCharges'}>],
#        [<AxesSubplot:title={'center':'Churn'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
pd.plotting.scatter_matrix(df,figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='customerID', ylabel='customerID'>,
#         <AxesSubplot:xlabel='gender', ylabel='customerID'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='customerID'>,
#         <AxesSubplot:xlabel='Partner', ylabel='customerID'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='customerID'>,
#         <AxesSubplot:xlabel='tenure', ylabel='customerID'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='customerID'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='customerID'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='customerID'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='customerID'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='customerID'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='customerID'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='customerID'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='customerID'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='customerID'>,
#         <AxesSubplot:xlabel='Contract', ylabel='customerID'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='customerID'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='customerID'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='customerID'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='customerID'>,
#         <AxesSubplot:xlabel='Churn', ylabel='customerID'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='gender'>,
#         <AxesSubplot:xlabel='gender', ylabel='gender'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='gender'>,
#         <AxesSubplot:xlabel='Partner', ylabel='gender'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='gender'>,
#         <AxesSubplot:xlabel='tenure', ylabel='gender'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='gender'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='gender'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='gender'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='gender'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='gender'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='gender'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='gender'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='gender'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='gender'>,
#         <AxesSubplot:xlabel='Contract', ylabel='gender'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='gender'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='gender'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='gender'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='gender'>,
#         <AxesSubplot:xlabel='Churn', ylabel='gender'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='gender', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='Partner', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='tenure', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='Contract', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='SeniorCitizen'>,
#         <AxesSubplot:xlabel='Churn', ylabel='SeniorCitizen'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='Partner'>,
#         <AxesSubplot:xlabel='gender', ylabel='Partner'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='Partner'>,
#         <AxesSubplot:xlabel='Partner', ylabel='Partner'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='Partner'>,
#         <AxesSubplot:xlabel='tenure', ylabel='Partner'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='Partner'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='Partner'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='Partner'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='Partner'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='Partner'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='Partner'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='Partner'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='Partner'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='Partner'>,
#         <AxesSubplot:xlabel='Contract', ylabel='Partner'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='Partner'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='Partner'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='Partner'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='Partner'>,
#         <AxesSubplot:xlabel='Churn', ylabel='Partner'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='gender', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='Partner', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='tenure', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='Contract', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='Dependents'>,
#         <AxesSubplot:xlabel='Churn', ylabel='Dependents'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='tenure'>,
#         <AxesSubplot:xlabel='gender', ylabel='tenure'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='tenure'>,
#         <AxesSubplot:xlabel='Partner', ylabel='tenure'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='tenure'>,
#         <AxesSubplot:xlabel='tenure', ylabel='tenure'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='tenure'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='tenure'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='tenure'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='tenure'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='tenure'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='tenure'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='tenure'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='tenure'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='tenure'>,
#         <AxesSubplot:xlabel='Contract', ylabel='tenure'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='tenure'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='tenure'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='tenure'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='tenure'>,
#         <AxesSubplot:xlabel='Churn', ylabel='tenure'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='gender', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='Partner', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='tenure', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='Contract', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='PhoneService'>,
#         <AxesSubplot:xlabel='Churn', ylabel='PhoneService'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='gender', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='Partner', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='tenure', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='Contract', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='MultipleLines'>,
#         <AxesSubplot:xlabel='Churn', ylabel='MultipleLines'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='gender', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='Partner', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='tenure', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='Contract', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='InternetService'>,
#         <AxesSubplot:xlabel='Churn', ylabel='InternetService'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='gender', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='Partner', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='tenure', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='Contract', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='OnlineSecurity'>,
#         <AxesSubplot:xlabel='Churn', ylabel='OnlineSecurity'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='gender', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='Partner', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='tenure', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='Contract', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='OnlineBackup'>,
#         <AxesSubplot:xlabel='Churn', ylabel='OnlineBackup'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='gender', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='Partner', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='tenure', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='Contract', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='DeviceProtection'>,
#         <AxesSubplot:xlabel='Churn', ylabel='DeviceProtection'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='gender', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='Partner', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='tenure', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='Contract', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='TechSupport'>,
#         <AxesSubplot:xlabel='Churn', ylabel='TechSupport'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='gender', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='Partner', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='tenure', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='Contract', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='StreamingTV'>,
#         <AxesSubplot:xlabel='Churn', ylabel='StreamingTV'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='gender', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='Partner', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='tenure', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='Contract', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='StreamingMovies'>,
#         <AxesSubplot:xlabel='Churn', ylabel='StreamingMovies'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='Contract'>,
#         <AxesSubplot:xlabel='gender', ylabel='Contract'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='Contract'>,
#         <AxesSubplot:xlabel='Partner', ylabel='Contract'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='Contract'>,
#         <AxesSubplot:xlabel='tenure', ylabel='Contract'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='Contract'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='Contract'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='Contract'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='Contract'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='Contract'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='Contract'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='Contract'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='Contract'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='Contract'>,
#         <AxesSubplot:xlabel='Contract', ylabel='Contract'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='Contract'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='Contract'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='Contract'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='Contract'>,
#         <AxesSubplot:xlabel='Churn', ylabel='Contract'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='gender', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='Partner', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='tenure', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='Contract', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='PaperlessBilling'>,
#         <AxesSubplot:xlabel='Churn', ylabel='PaperlessBilling'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='gender', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='Partner', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='tenure', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='Contract', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='PaymentMethod'>,
#         <AxesSubplot:xlabel='Churn', ylabel='PaymentMethod'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='gender', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='Partner', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='tenure', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='Contract', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='MonthlyCharges'>,
#         <AxesSubplot:xlabel='Churn', ylabel='MonthlyCharges'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='gender', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='Partner', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='tenure', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='Contract', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='TotalCharges'>,
#         <AxesSubplot:xlabel='Churn', ylabel='TotalCharges'>],
#        [<AxesSubplot:xlabel='customerID', ylabel='Churn'>,
#         <AxesSubplot:xlabel='gender', ylabel='Churn'>,
#         <AxesSubplot:xlabel='SeniorCitizen', ylabel='Churn'>,
#         <AxesSubplot:xlabel='Partner', ylabel='Churn'>,
#         <AxesSubplot:xlabel='Dependents', ylabel='Churn'>,
#         <AxesSubplot:xlabel='tenure', ylabel='Churn'>,
#         <AxesSubplot:xlabel='PhoneService', ylabel='Churn'>,
#         <AxesSubplot:xlabel='MultipleLines', ylabel='Churn'>,
#         <AxesSubplot:xlabel='InternetService', ylabel='Churn'>,
#         <AxesSubplot:xlabel='OnlineSecurity', ylabel='Churn'>,
#         <AxesSubplot:xlabel='OnlineBackup', ylabel='Churn'>,
#         <AxesSubplot:xlabel='DeviceProtection', ylabel='Churn'>,
#         <AxesSubplot:xlabel='TechSupport', ylabel='Churn'>,
#         <AxesSubplot:xlabel='StreamingTV', ylabel='Churn'>,
#         <AxesSubplot:xlabel='StreamingMovies', ylabel='Churn'>,
#         <AxesSubplot:xlabel='Contract', ylabel='Churn'>,
#         <AxesSubplot:xlabel='PaperlessBilling', ylabel='Churn'>,
#         <AxesSubplot:xlabel='PaymentMethod', ylabel='Churn'>,
#         <AxesSubplot:xlabel='MonthlyCharges', ylabel='Churn'>,
#         <AxesSubplot:xlabel='TotalCharges', ylabel='Churn'>,
#         <AxesSubplot:xlabel='Churn', ylabel='Churn'>]], dtype=object)

# %%
plt.figure(figsize=(22,7))
df.corr()['Churn'].sort_values(ascending=False).drop(['Churn']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=13)
plt.ylabel('column with target names',fontsize=14)
plt.title('CORRELATION',fontsize=18)
plt.show()

# %%
#The EDA is complete, training the data is next
#dividing the data into features and label
x= df.drop('Churn',axis=1)
y=df['Churn']

# %%
#training the data 
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression

# %%
lr=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test,=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i},the training accuracy is = {r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is = {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is = 0.2776621537441537
# At random state 0,the testing accuracy is = 0.23037294934556962
#
#
# At random state 1,the training accuracy is = 0.26778906824187565
# At random state 1,the testing accuracy is = 0.2697688809347203
#
#
# At random state 2,the training accuracy is = 0.2728448480236647
# At random state 2,the testing accuracy is = 0.24882577747218348
#
#
# At random state 3,the training accuracy is = 0.2637129910083147
# At random state 3,the testing accuracy is = 0.2885692713279322
#
#
# At random state 4,the training accuracy is = 0.27926904758810644
# At random state 4,the testing accuracy is = 0.2251758906871747
#
#
# At random state 5,the training accuracy is = 0.267892854585983
# At random state 5,the testing accuracy is = 0.27013696324995584
#
#
# At random state 6,the training accuracy is = 0.27138223447766485
# At random state 6,the testing accuracy is = 0.2564816106882367
#
#
# At random state 7,the training accuracy is = 0.26578751659192956
# At random state 7,the testing accuracy is = 0.2784085174359979
#
#
# At random state 8,the training accuracy is = 0.2722849816848958
# At random state 8,the testing accuracy is = 0.2525657115797122
#
#
# At random state 9,the training accuracy is = 0.27482800139997543
# At random state 9,the testing accuracy is = 0.24193455003588127
#
#
# At random state 10,the training accuracy is = 0.27377998328399866
# At random state 10,the testing accuracy is = 0.24287408804559096
#
#
# At random state 11,the training accuracy is = 0.264663216049402
# At random state 11,the testing accuracy is = 0.284598463995983
#
#
# At random state 12,the training accuracy is = 0.2743425200585081
# At random state 12,the testing accuracy is = 0.24572892606533958
#
#
# At random state 13,the training accuracy is = 0.2669556013889727
# At random state 13,the testing accuracy is = 0.275040246051794
#
#
# At random state 14,the training accuracy is = 0.2695244151403413
# At random state 14,the testing accuracy is = 0.26212066140953005
#
#
# At random state 15,the training accuracy is = 0.2698865910889081
# At random state 15,the testing accuracy is = 0.2636023996057354
#
#
# At random state 16,the training accuracy is = 0.2732309598027005
# At random state 16,the testing accuracy is = 0.2480029695633299
#
#
# At random state 17,the training accuracy is = 0.2716301987058396
# At random state 17,the testing accuracy is = 0.2546986163803431
#
#
# At random state 18,the training accuracy is = 0.26533247524186665
# At random state 18,the testing accuracy is = 0.2808332203948193
#
#
# At random state 19,the training accuracy is = 0.2632840888164988
# At random state 19,the testing accuracy is = 0.2902800940731942
#
#
# At random state 20,the training accuracy is = 0.2679103367562844
# At random state 20,the testing accuracy is = 0.26936222919094166
#
#
# At random state 21,the training accuracy is = 0.27616624925086986
# At random state 21,the testing accuracy is = 0.2378175081204481
#
#
# At random state 22,the training accuracy is = 0.27488977851296126
# At random state 22,the testing accuracy is = 0.241554541953787
#
#
# At random state 23,the training accuracy is = 0.27272416988067383
# At random state 23,the testing accuracy is = 0.2504365413221724
#
#
# At random state 24,the training accuracy is = 0.26703766917681704
# At random state 24,the testing accuracy is = 0.2740907388300806
#
#
# At random state 25,the training accuracy is = 0.2629005353824838
# At random state 25,the testing accuracy is = 0.2916083189609133
#
#
# At random state 26,the training accuracy is = 0.2720639583929876
# At random state 26,the testing accuracy is = 0.25514362018871284
#
#
# At random state 27,the training accuracy is = 0.26771207854395773
# At random state 27,the testing accuracy is = 0.2682361338275737
#
#
# At random state 28,the training accuracy is = 0.27111668401687805
# At random state 28,the testing accuracy is = 0.25758470242085063
#
#
# At random state 29,the training accuracy is = 0.2751510064269522
# At random state 29,the testing accuracy is = 0.24325637143371504
#
#
# At random state 30,the training accuracy is = 0.2668564783370976
# At random state 30,the testing accuracy is = 0.27078435879929175
#
#
# At random state 31,the training accuracy is = 0.2680785285477628
# At random state 31,the testing accuracy is = 0.2695349522031091
#
#
# At random state 32,the training accuracy is = 0.2664675546887805
# At random state 32,the testing accuracy is = 0.2722785569998565
#
#
# At random state 33,the training accuracy is = 0.274719062167729
# At random state 33,the testing accuracy is = 0.2441191612427448
#
#
# At random state 34,the training accuracy is = 0.2722221359015238
# At random state 34,the testing accuracy is = 0.25332608612030416
#
#
# At random state 35,the training accuracy is = 0.26583723827373107
# At random state 35,the testing accuracy is = 0.27871393087284535
#
#
# At random state 36,the training accuracy is = 0.2635872171685114
# At random state 36,the testing accuracy is = 0.2854650180049181
#
#
# At random state 37,the training accuracy is = 0.26699933424397027
# At random state 37,the testing accuracy is = 0.27228250919496877
#
#
# At random state 38,the training accuracy is = 0.2610821623297461
# At random state 38,the testing accuracy is = 0.29643081309406005
#
#
# At random state 39,the training accuracy is = 0.2673948644397971
# At random state 39,the testing accuracy is = 0.27143625480118105
#
#
# At random state 40,the training accuracy is = 0.276088978546535
# At random state 40,the testing accuracy is = 0.23845980748102846
#
#
# At random state 41,the training accuracy is = 0.27268069175346976
# At random state 41,the testing accuracy is = 0.25231101841947656
#
#
# At random state 42,the training accuracy is = 0.26268303490382183
# At random state 42,the testing accuracy is = 0.2932909044601386
#
#
# At random state 43,the training accuracy is = 0.2636427534150947
# At random state 43,the testing accuracy is = 0.28750015455137334
#
#
# At random state 44,the training accuracy is = 0.2660817316011107
# At random state 44,the testing accuracy is = 0.27881008176346167
#
#
# At random state 45,the training accuracy is = 0.2725198365396052
# At random state 45,the testing accuracy is = 0.2501087139893007
#
#
# At random state 46,the training accuracy is = 0.27055501077919863
# At random state 46,the testing accuracy is = 0.260772254362729
#
#
# At random state 47,the training accuracy is = 0.271861164534663
# At random state 47,the testing accuracy is = 0.25487433728401887
#
#
# At random state 48,the training accuracy is = 0.26714377099088804
# At random state 48,the testing accuracy is = 0.2741823406495829
#
#
# At random state 49,the training accuracy is = 0.2666974716880718
# At random state 49,the testing accuracy is = 0.27527345606357867
#
#
# At random state 50,the training accuracy is = 0.2714846396269579
# At random state 50,the testing accuracy is = 0.2560325244145568
#
#
# At random state 51,the training accuracy is = 0.27462748486594657
# At random state 51,the testing accuracy is = 0.24416582207212323
#
#
# At random state 52,the training accuracy is = 0.267988493686912
# At random state 52,the testing accuracy is = 0.27230318962640687
#
#
# At random state 53,the training accuracy is = 0.2671838419634429
# At random state 53,the testing accuracy is = 0.2747087341395883
#
#
# At random state 54,the training accuracy is = 0.27390606896410696
# At random state 54,the testing accuracy is = 0.24832005924716327
#
#
# At random state 55,the training accuracy is = 0.2706058482163083
# At random state 55,the testing accuracy is = 0.2600904616416627
#
#
# At random state 56,the training accuracy is = 0.2662846991707739
# At random state 56,the testing accuracy is = 0.2786917746731298
#
#
# At random state 57,the training accuracy is = 0.26379592571147303
# At random state 57,the testing accuracy is = 0.288107073330104
#
#
# At random state 58,the training accuracy is = 0.26694609285948256
# At random state 58,the testing accuracy is = 0.2755625591900186
#
#
# At random state 59,the training accuracy is = 0.26988504690136417
# At random state 59,the testing accuracy is = 0.26217927166006905
#
#
# At random state 60,the training accuracy is = 0.2725105364001086
# At random state 60,the testing accuracy is = 0.2528752369974907
#
#
# At random state 61,the training accuracy is = 0.26511342624034473
# At random state 61,the testing accuracy is = 0.28075773097041246
#
#
# At random state 62,the training accuracy is = 0.2689061016444211
# At random state 62,the testing accuracy is = 0.26785606894363245
#
#
# At random state 63,the training accuracy is = 0.26584186749458405
# At random state 63,the testing accuracy is = 0.2763867379972613
#
#
# At random state 64,the training accuracy is = 0.2689146186977177
# At random state 64,the testing accuracy is = 0.2681643000937284
#
#
# At random state 65,the training accuracy is = 0.26653689433529815
# At random state 65,the testing accuracy is = 0.27777663529626917
#
#
# At random state 66,the training accuracy is = 0.2679941286951787
# At random state 66,the testing accuracy is = 0.2688949343934113
#
#
# At random state 67,the training accuracy is = 0.2664566650578657
# At random state 67,the testing accuracy is = 0.2775157442649514
#
#
# At random state 68,the training accuracy is = 0.27183812511920236
# At random state 68,the testing accuracy is = 0.25535042555733656
#
#
# At random state 69,the training accuracy is = 0.2706628205940952
# At random state 69,the testing accuracy is = 0.2595493145913821
#
#
# At random state 70,the training accuracy is = 0.27174755094689473
# At random state 70,the testing accuracy is = 0.2550511253579518
#
#
# At random state 71,the training accuracy is = 0.26690819133242716
# At random state 71,the testing accuracy is = 0.27503694429914016
#
#
# At random state 72,the training accuracy is = 0.2685965488567027
# At random state 72,the testing accuracy is = 0.26794461595735886
#
#
# At random state 73,the training accuracy is = 0.27042173569208905
# At random state 73,the testing accuracy is = 0.2557419481259786
#
#
# At random state 74,the training accuracy is = 0.26995483054952996
# At random state 74,the testing accuracy is = 0.2636085420695916
#
#
# At random state 75,the training accuracy is = 0.2687137208792415
# At random state 75,the testing accuracy is = 0.2676502979362083
#
#
# At random state 76,the training accuracy is = 0.26564412873945265
# At random state 76,the testing accuracy is = 0.279859838346065
#
#
# At random state 77,the training accuracy is = 0.27257688868143004
# At random state 77,the testing accuracy is = 0.2524270292681986
#
#
# At random state 78,the training accuracy is = 0.2763370681198851
# At random state 78,the testing accuracy is = 0.23704233400290264
#
#
# At random state 79,the training accuracy is = 0.2697587400005237
# At random state 79,the testing accuracy is = 0.2631128152211395
#
#
# At random state 80,the training accuracy is = 0.2638925863644208
# At random state 80,the testing accuracy is = 0.2859610301361982
#
#
# At random state 81,the training accuracy is = 0.27505227981360747
# At random state 81,the testing accuracy is = 0.24280877748064567
#
#
# At random state 82,the training accuracy is = 0.2689293206726241
# At random state 82,the testing accuracy is = 0.2666900687885826
#
#
# At random state 83,the training accuracy is = 0.26575165245693666
# At random state 83,the testing accuracy is = 0.2796642574617043
#
#
# At random state 84,the training accuracy is = 0.2780295086862259
# At random state 84,the testing accuracy is = 0.2291105805473217
#
#
# At random state 85,the training accuracy is = 0.2730878547200417
# At random state 85,the testing accuracy is = 0.24999523536161972
#
#
# At random state 86,the training accuracy is = 0.2745723185825656
# At random state 86,the testing accuracy is = 0.2438494722802056
#
#
# At random state 87,the training accuracy is = 0.2717453712617237
# At random state 87,the testing accuracy is = 0.25657770778990063
#
#
# At random state 88,the training accuracy is = 0.2663797585197316
# At random state 88,the testing accuracy is = 0.27721966593544844
#
#
# At random state 89,the training accuracy is = 0.2653510204430416
# At random state 89,the testing accuracy is = 0.28127974230106745
#
#
# At random state 90,the training accuracy is = 0.275162856123746
# At random state 90,the testing accuracy is = 0.24207861396289287
#
#
# At random state 91,the training accuracy is = 0.27396288412783987
# At random state 91,the testing accuracy is = 0.24862498290399682
#
#
# At random state 92,the training accuracy is = 0.2624913924111544
# At random state 92,the testing accuracy is = 0.2940202144033305
#
#
# At random state 93,the training accuracy is = 0.27505308810653606
# At random state 93,the testing accuracy is = 0.24320264692487303
#
#
# At random state 94,the training accuracy is = 0.27380871053522826
# At random state 94,the testing accuracy is = 0.2478373877373412
#
#
# At random state 95,the training accuracy is = 0.27902886151612527
# At random state 95,the testing accuracy is = 0.22735379737785721
#
#
# At random state 96,the training accuracy is = 0.26982883693076765
# At random state 96,the testing accuracy is = 0.2639594935448778
#
#
# At random state 97,the training accuracy is = 0.27762744076302415
# At random state 97,the testing accuracy is = 0.22863637763012978
#
#
# At random state 98,the training accuracy is = 0.27298313968307675
# At random state 98,the testing accuracy is = 0.24672432144546086
#
#
# At random state 99,the training accuracy is = 0.2684897038540568
# At random state 99,the testing accuracy is = 0.2685097872221197

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=49)

# %%
pred_test=lr.predict(x_test)

# %%
pred_train=lr.predict(x_train)

# %%
print(r2_score(y_test,pred_test)*100)
# Out:
# 27.916574662937

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
lr.fit(x_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
pred_test=lr.predict(x_test)
pred_test
# Out:
# array([-0.11401597,  0.13527507,  0.3559524 , ...,  0.11008938,
#         0.3798592 ,  0.20978295])

# %%
pred_train=lr.predict(x_train)
pred_train
# Out:
# array([-0.02021987,  0.43956162,  0.29129166, ...,  0.18884021,
#         0.28005936,  0.38487708])

# %%
lr_accuracy=round(lr.score(x_train,y_train)*100)
lr_accuracy
# Out:
# 27

# %%
from sklearn.tree import DecisionTreeRegressor
tree=DecisionTreeRegressor(max_depth=15, min_samples_leaf=2)
tree.fit(x_train,y_train)
tree_pred=tree.predict(x_test)
tree_pred
# Out:
# array([0., 0., 1., ..., 0., 0., 1.])

# %%
tree_accuracy=round(tree.score(x_train,y_train)*100)
tree_accuracy
# Out:
# 80

# %%
from sklearn.ensemble import RandomForestRegressor 
rf=RandomForestRegressor(n_estimators=400,max_depth=6,min_samples_leaf=2,n_jobs=4)
rf.fit(x_train,y_train)
rf.pred=rf.predict(x_test)

# %%
rf_accuracy=round(rf.score(x_train,y_train)*100)
rf_accuracy
# Out:
# 38

# %%
import xgboost
from xgboost import XGBRegressor

model=XGBRegressor(n_estimators=100,learning_rate=0.05)
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([0.03974981, 0.09128155, 0.28769353, ..., 0.01398199, 0.20563431,
#        0.16833259], dtype=float32)

# %%
model.score(x_train,y_train)*100
# Out:
# 52.243942356724624

# %%
model_accuracy=round(model.score(x_train,y_train)*100)
model_accuracy
# Out:
# 52

# %%
#Cross validation  for desisiontree
scr=cross_val_score(tree,x,y,cv=5)
scr.mean()
print("Cross validation score of DecisionTreeRegression:",scr.mean())
# Out:
# Cross validation score of DecisionTreeRegression: -0.20047413179166312

# %% [markdown]
# The training process is complete and the churn model has been smoothly made.

# %%
#saving the model
import pickle 
filename='churn.pkl'
pickle.dump(tree,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('churn.pkl','rb'))
result=loaded_model.score(x_test,y_test)*-100
result
# Out:
# 19.491393497133114

# %%
#creatig a new df
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_train[:]],index=["Predicted","Original"])

# %%
conclusion
# Out:
#               0         1         2         3         4         5     \
# Predicted  0.00000  0.000000  1.000000  0.000000  0.000000  0.746269
# Original  -0.02022  0.439562  0.291292  0.453972  0.625984  0.235406
#
#                6         7         8        9     ...      5624      5625  \
# Predicted  0.000000  1.000000  0.666667  0.00000  ...       NaN       NaN
# Original  -0.167511 -0.023337 -0.122331  0.20806  ...  0.245545 -0.085224
#
#                5626      5627      5628      5629      5630     5631  \
# Predicted       NaN       NaN       NaN       NaN       NaN      NaN
# Original   0.110721  0.331018  0.403879  0.271661  0.562829  0.18884
#
#                5632      5633
# Predicted       NaN       NaN
# Original   0.280059  0.384877
#
# [2 rows x 5634 columns]
