# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv")

# %%
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7750.000000   7682.000000   7682.000000  7677.000000  7677.000000
# mean     13.000000     29.768211     23.225059    56.759372    88.374804
# std       7.211568      2.969999      2.413961    14.668111     7.192004
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.700000    45.963543    84.222862
# 50%      13.000000     29.900000     23.400000    55.039024    89.793480
# 75%      19.000000     32.000000     24.900000    67.190056    93.743629
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7677.000000       7677.000000  7677.000000  7677.000000
# mean          29.613447         23.512589     7.097875    62.505019
# std            2.947191          2.345347     2.183836    33.730589
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.673499         22.089739     5.678705    37.266753
# 50%           29.703426         23.760199     6.547470    56.865482
# 75%           31.710450         25.152909     8.032276    84.223616
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1  ...   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  7677.000000  ...  7677.000000  7677.000000  7677.000000  7752.000000
# mean      0.368774  ...     0.485003     0.278200     0.269407    37.544722
# std       0.262458  ...     1.762807     1.161809     1.206214     0.050352
# min       0.000000  ...     0.000000     0.000000     0.000000    37.456200
# 25%       0.146654  ...     0.000000     0.000000     0.000000    37.510200
# 50%       0.315697  ...     0.000000     0.000000     0.000000    37.550700
# 75%       0.575489  ...     0.018364     0.007896     0.000041    37.577600
# max       0.967277  ...    21.621661    15.841235    16.655469    37.645000
#
#                lon          DEM        Slope  Solar radiation    Next_Tmax  \
# count  7752.000000  7752.000000  7752.000000      7752.000000  7725.000000
# mean    126.991397    61.867972     1.257048      5341.502803    30.274887
# std       0.079435    54.279780     1.370444       429.158867     3.128010
# min     126.826000    12.370000     0.098475      4329.520508    17.400000
# 25%     126.937000    28.700000     0.271300      4999.018555    28.200000
# 50%     126.995000    45.716000     0.618000      5436.345215    30.500000
# 75%     127.042000    59.832400     1.767800      5728.316406    32.600000
# max     127.135000   212.335000     5.178230      5992.895996    38.900000
#
#          Next_Tmin
# count  7725.000000
# mean     22.932220
# std       2.487613
# min      11.300000
# 25%      21.300000
# 50%      23.100000
# 75%      24.600000
# max      29.800000
#
# [8 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
#  16  LDAPS_PPT3        7677 non-null   float64
#  17  LDAPS_PPT4        7677 non-null   float64
#  18  lat               7752 non-null   float64
#  19  lon               7752 non-null   float64
#  20  DEM               7752 non-null   float64
#  21  Slope             7752 non-null   float64
#  22  Solar radiation   7752 non-null   float64
#  23  Next_Tmax         7725 non-null   float64
#  24  Next_Tmin         7725 non-null   float64
# dtypes: float64(24), object(1)
# memory usage: 1.5+ MB

# %%
df.dtypes
# Out:
# station             float64
# Date                 object
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
#Since date is an object, I will use the transformer to transform it.
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Date']=le.fit_transform(df['Date'])

# %%
df.dtypes
# Out:
# station             float64
# Date                  int32
# Present_Tmax        float64
# Present_Tmin        float64
# LDAPS_RHmin         float64
# LDAPS_RHmax         float64
# LDAPS_Tmax_lapse    float64
# LDAPS_Tmin_lapse    float64
# LDAPS_WS            float64
# LDAPS_LH            float64
# LDAPS_CC1           float64
# LDAPS_CC2           float64
# LDAPS_CC3           float64
# LDAPS_CC4           float64
# LDAPS_PPT1          float64
# LDAPS_PPT2          float64
# LDAPS_PPT3          float64
# LDAPS_PPT4          float64
# lat                 float64
# lon                 float64
# DEM                 float64
# Slope               float64
# Solar radiation     float64
# Next_Tmax           float64
# Next_Tmin           float64
# dtype: object

# %%
df.isnull().all()
# Out:
# station             False
# Date                False
# Present_Tmax        False
# Present_Tmin        False
# LDAPS_RHmin         False
# LDAPS_RHmax         False
# LDAPS_Tmax_lapse    False
# LDAPS_Tmin_lapse    False
# LDAPS_WS            False
# LDAPS_LH            False
# LDAPS_CC1           False
# LDAPS_CC2           False
# LDAPS_CC3           False
# LDAPS_CC4           False
# LDAPS_PPT1          False
# LDAPS_PPT2          False
# LDAPS_PPT3          False
# LDAPS_PPT4          False
# lat                 False
# lon                 False
# DEM                 False
# Slope               False
# Solar radiation     False
# Next_Tmax           False
# Next_Tmin           False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 0
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %% [markdown]
# To get rid of null values, we would replace them

# %%
#null values heatmap
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %%
#getting rid of null values.
df=df.dropna()

# %%
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %% [markdown]
# We've gotten rid of the null values.

# %%
df.corr()
# Out:
#                    station      Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000 -0.000715      0.113301      0.133282    -0.067846
# Date             -0.000715  1.000000     -0.146496     -0.111579    -0.067058
# Present_Tmax      0.113301 -0.146496      1.000000      0.615208    -0.209059
# Present_Tmin      0.133282 -0.111579      0.615208      1.000000     0.122200
# LDAPS_RHmin      -0.067846 -0.067058     -0.209059      0.122200     1.000000
# LDAPS_RHmax      -0.169351 -0.020033     -0.306943     -0.018576     0.578358
# LDAPS_Tmax_lapse  0.069856 -0.156790      0.573777      0.467904    -0.569580
# LDAPS_Tmin_lapse  0.105277 -0.170950      0.628705      0.772061     0.085237
# LDAPS_WS          0.005822 -0.045268     -0.125952     -0.038779     0.289422
# LDAPS_LH         -0.132129 -0.016547      0.134246     -0.012817    -0.072195
# LDAPS_CC1         0.006539 -0.031769     -0.316333      0.084348     0.612831
# LDAPS_CC2         0.003526 -0.014821     -0.216976      0.090038     0.744774
# LDAPS_CC3        -0.000161 -0.054371     -0.146391     -0.004719     0.688069
# LDAPS_CC4         0.005005 -0.041425     -0.143069     -0.046694     0.513937
# LDAPS_PPT1       -0.001954 -0.022818     -0.114917      0.111577     0.259039
# LDAPS_PPT2       -0.007635 -0.007071     -0.104779      0.066207     0.389572
# LDAPS_PPT3       -0.013865  0.004353     -0.127248     -0.052428     0.237512
# LDAPS_PPT4       -0.011085 -0.033356     -0.107295     -0.070391     0.167311
# lat              -0.239118  0.000843     -0.054134     -0.081417     0.085027
# lon              -0.118845 -0.002541      0.007695     -0.045174    -0.077590
# DEM              -0.256706  0.000970     -0.189439     -0.254084     0.100684
# Slope            -0.091721  0.000656     -0.107079     -0.148423     0.122454
# Solar radiation  -0.021194 -0.440095     -0.022114      0.059765     0.242168
# Next_Tmax         0.107747 -0.122909      0.610357      0.463523    -0.446824
# Next_Tmin         0.128184 -0.133403      0.621048      0.796975     0.093249
#
#                   LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  \
# station             -0.169351          0.069856          0.105277  0.005822
# Date                -0.020033         -0.156790         -0.170950 -0.045268
# Present_Tmax        -0.306943          0.573777          0.628705 -0.125952
# Present_Tmin        -0.018576          0.467904          0.772061 -0.038779
# LDAPS_RHmin          0.578358         -0.569580          0.085237  0.289422
# LDAPS_RHmax          1.000000         -0.377293         -0.118965  0.131269
# LDAPS_Tmax_lapse    -0.377293          1.000000          0.653425 -0.316011
# LDAPS_Tmin_lapse    -0.118965          0.653425          1.000000 -0.134652
# LDAPS_WS             0.131269         -0.316011         -0.134652  1.000000
# LDAPS_LH             0.238986          0.043663         -0.139675  0.004427
# LDAPS_CC1            0.435937         -0.440878          0.008714  0.285349
# LDAPS_CC2            0.390620         -0.525380          0.046537  0.257226
# LDAPS_CC3            0.224734         -0.542728         -0.044998  0.238155
# LDAPS_CC4            0.127242         -0.429739         -0.079536  0.218870
# LDAPS_PPT1           0.268019         -0.115659          0.034956  0.141503
# LDAPS_PPT2           0.227581         -0.248369         -0.002743  0.181634
# LDAPS_PPT3           0.132436         -0.193749         -0.093116  0.147199
# LDAPS_PPT4           0.118101         -0.170415         -0.103541  0.134428
# lat                  0.194820         -0.044052         -0.099452  0.033025
# lon                  0.025563          0.091568         -0.024703 -0.063009
# DEM                  0.176557         -0.181433         -0.198396  0.188540
# Slope                0.219436         -0.163891         -0.187864  0.169223
# Solar radiation      0.146622          0.047414          0.157763  0.120630
# Next_Tmax           -0.289788          0.835729          0.592119 -0.351107
# Next_Tmin           -0.076415          0.589963          0.886513 -0.102021
#
#                   LDAPS_LH  ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4       lat  \
# station          -0.132129  ...   -0.007635   -0.013865   -0.011085 -0.239118
# Date             -0.016547  ...   -0.007071    0.004353   -0.033356  0.000843
# Present_Tmax      0.134246  ...   -0.104779   -0.127248   -0.107295 -0.054134
# Present_Tmin     -0.012817  ...    0.066207   -0.052428   -0.070391 -0.081417
# LDAPS_RHmin      -0.072195  ...    0.389572    0.237512    0.167311  0.085027
# LDAPS_RHmax       0.238986  ...    0.227581    0.132436    0.118101  0.194820
# LDAPS_Tmax_lapse  0.043663  ...   -0.248369   -0.193749   -0.170415 -0.044052
# LDAPS_Tmin_lapse -0.139675  ...   -0.002743   -0.093116   -0.103541 -0.099452
# LDAPS_WS          0.004427  ...    0.181634    0.147199    0.134428  0.033025
# LDAPS_LH          1.000000  ...   -0.084375    0.009495    0.012372  0.133309
# LDAPS_CC1        -0.148314  ...    0.389368    0.166763    0.088897 -0.010268
# LDAPS_CC2        -0.265382  ...    0.479511    0.238179    0.157194 -0.002642
# LDAPS_CC3        -0.246709  ...    0.336254    0.337346    0.303787  0.003827
# LDAPS_CC4        -0.173156  ...    0.286266    0.265709    0.380597 -0.010612
# LDAPS_PPT1       -0.018708  ...    0.367922    0.012847    0.004377 -0.005841
# LDAPS_PPT2       -0.084375  ...    1.000000    0.205285    0.121937  0.015198
# LDAPS_PPT3        0.009495  ...    0.205285    1.000000    0.288093  0.031822
# LDAPS_PPT4        0.012372  ...    0.121937    0.288093    1.000000  0.008178
# lat               0.133309  ...    0.015198    0.031822    0.008178  1.000000
# lon               0.024476  ...    0.016958    0.018094    0.041095  0.289999
# DEM               0.056362  ...    0.002411    0.011345   -0.009830  0.029344
# Slope             0.087517  ...    0.003703    0.018372   -0.008689  0.071446
# Solar radiation  -0.044956  ...    0.107620   -0.057430    0.033249  0.036514
# Next_Tmax         0.156779  ...   -0.186722   -0.203554   -0.190720 -0.055367
# Next_Tmin        -0.060392  ...   -0.012462   -0.068664   -0.114900 -0.085136
#
#                        lon       DEM     Slope  Solar radiation  Next_Tmax  \
# station          -0.118845 -0.256706 -0.091721        -0.021194   0.107747
# Date             -0.002541  0.000970  0.000656        -0.440095  -0.122909
# Present_Tmax      0.007695 -0.189439 -0.107079        -0.022114   0.610357
# Present_Tmin     -0.045174 -0.254084 -0.148423         0.059765   0.463523
# LDAPS_RHmin      -0.077590  0.100684  0.122454         0.242168  -0.446824
# LDAPS_RHmax       0.025563  0.176557  0.219436         0.146622  -0.289788
# LDAPS_Tmax_lapse  0.091568 -0.181433 -0.163891         0.047414   0.835729
# LDAPS_Tmin_lapse -0.024703 -0.198396 -0.187864         0.157763   0.592119
# LDAPS_WS         -0.063009  0.188540  0.169223         0.120630  -0.351107
# LDAPS_LH          0.024476  0.056362  0.087517        -0.044956   0.156779
# LDAPS_CC1        -0.007962 -0.017378 -0.023893         0.218285  -0.459705
# LDAPS_CC2        -0.004757 -0.016249 -0.021173         0.169346  -0.498295
# LDAPS_CC3         0.013948 -0.001249 -0.005903         0.116691  -0.523061
# LDAPS_CC4        -0.004456 -0.010240 -0.017891         0.114268  -0.454039
# LDAPS_PPT1       -0.004375  0.005412  0.010340         0.084804  -0.125954
# LDAPS_PPT2        0.016958  0.002411  0.003703         0.107620  -0.186722
# LDAPS_PPT3        0.018094  0.011345  0.018372        -0.057430  -0.203554
# LDAPS_PPT4        0.041095 -0.009830 -0.008689         0.033249  -0.190720
# lat               0.289999  0.029344  0.071446         0.036514  -0.055367
# lon               1.000000  0.006685  0.037616         0.005178   0.003502
# DEM               0.006685  1.000000  0.784179         0.053241  -0.174578
# Slope             0.037616  0.784179  1.000000         0.025517  -0.104279
# Solar radiation   0.005178  0.053241  0.025517         1.000000   0.016145
# Next_Tmax         0.003502 -0.174578 -0.104279         0.016145   1.000000
# Next_Tmin        -0.045758 -0.249303 -0.148379         0.125517   0.616629
#
#                   Next_Tmin
# station            0.128184
# Date              -0.133403
# Present_Tmax       0.621048
# Present_Tmin       0.796975
# LDAPS_RHmin        0.093249
# LDAPS_RHmax       -0.076415
# LDAPS_Tmax_lapse   0.589963
# LDAPS_Tmin_lapse   0.886513
# LDAPS_WS          -0.102021
# LDAPS_LH          -0.060392
# LDAPS_CC1         -0.012877
# LDAPS_CC2          0.030358
# LDAPS_CC3         -0.056490
# LDAPS_CC4         -0.086197
# LDAPS_PPT1         0.018031
# LDAPS_PPT2        -0.012462
# LDAPS_PPT3        -0.068664
# LDAPS_PPT4        -0.114900
# lat               -0.085136
# lon               -0.045758
# DEM               -0.249303
# Slope             -0.148379
# Solar radiation    0.125517
# Next_Tmax          0.616629
# Next_Tmin          1.000000
#
# [25 rows x 25 columns]

# %%
#correlation heatmap
plt.figure(figsize=(22,10))
sns.heatmap(df.corr(), annot=True,fmt="0.2f",linewidth=0.1,linecolor="black")
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# station            -0.004178
# Date               -0.001744
# Present_Tmax       -0.257069
# Present_Tmin       -0.353822
# LDAPS_RHmin         0.301396
# LDAPS_RHmax        -0.845264
# LDAPS_Tmax_lapse   -0.222349
# LDAPS_Tmin_lapse   -0.574035
# LDAPS_WS            1.553926
# LDAPS_LH            0.662971
# LDAPS_CC1           0.456716
# LDAPS_CC2           0.473929
# LDAPS_CC3           0.639649
# LDAPS_CC4           0.663815
# LDAPS_PPT1          5.305906
# LDAPS_PPT2          5.710360
# LDAPS_PPT3          6.356670
# LDAPS_PPT4          6.681256
# lat                 0.085377
# lon                -0.289048
# DEM                 1.721617
# Slope               1.559050
# Solar radiation    -0.524325
# Next_Tmax          -0.334842
# Next_Tmin          -0.393662
# dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore')

#checking for outliers
plt.figure(figsize=(20,10))
for o in enumerate(df):
    plt.subplot(9,4,o[0]+1)
    sns.boxplot(df[o[1]])

# %%
#dealing with outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
print(np.where(z>3))
# Out:
# (array([  25,   25,   26, ..., 7581, 7582, 7582], dtype=int64), array([ 8, 15, 15, ...,  3,  3,  7], dtype=int64))

# %%
z=np.abs(zscore(df))
z.all()
# Out:
# station             True
# Date                True
# Present_Tmax        True
# Present_Tmin        True
# LDAPS_RHmin         True
# LDAPS_RHmax         True
# LDAPS_Tmax_lapse    True
# LDAPS_Tmin_lapse    True
# LDAPS_WS            True
# LDAPS_LH            True
# LDAPS_CC1           True
# LDAPS_CC2           True
# LDAPS_CC3           True
# LDAPS_CC4           True
# LDAPS_PPT1          True
# LDAPS_PPT2          True
# LDAPS_PPT3          True
# LDAPS_PPT4          True
# lat                 True
# lon                 True
# DEM                 True
# Slope               True
# Solar radiation     True
# Next_Tmax           True
# Next_Tmin           True
# dtype: bool

# %% [markdown]
# All the outliers are gone

# %%
df.hist(grid=False,figsize=(20,15),bins=30)
# Out:
# array([[<AxesSubplot:title={'center':'station'}>,
#         <AxesSubplot:title={'center':'Date'}>,
#         <AxesSubplot:title={'center':'Present_Tmax'}>,
#         <AxesSubplot:title={'center':'Present_Tmin'}>,
#         <AxesSubplot:title={'center':'LDAPS_RHmin'}>],
#        [<AxesSubplot:title={'center':'LDAPS_RHmax'}>,
#         <AxesSubplot:title={'center':'LDAPS_Tmax_lapse'}>,
#         <AxesSubplot:title={'center':'LDAPS_Tmin_lapse'}>,
#         <AxesSubplot:title={'center':'LDAPS_WS'}>,
#         <AxesSubplot:title={'center':'LDAPS_LH'}>],
#        [<AxesSubplot:title={'center':'LDAPS_CC1'}>,
#         <AxesSubplot:title={'center':'LDAPS_CC2'}>,
#         <AxesSubplot:title={'center':'LDAPS_CC3'}>,
#         <AxesSubplot:title={'center':'LDAPS_CC4'}>,
#         <AxesSubplot:title={'center':'LDAPS_PPT1'}>],
#        [<AxesSubplot:title={'center':'LDAPS_PPT2'}>,
#         <AxesSubplot:title={'center':'LDAPS_PPT3'}>,
#         <AxesSubplot:title={'center':'LDAPS_PPT4'}>,
#         <AxesSubplot:title={'center':'lat'}>,
#         <AxesSubplot:title={'center':'lon'}>],
#        [<AxesSubplot:title={'center':'DEM'}>,
#         <AxesSubplot:title={'center':'Slope'}>,
#         <AxesSubplot:title={'center':'Solar radiation'}>,
#         <AxesSubplot:title={'center':'Next_Tmax'}>,
#         <AxesSubplot:title={'center':'Next_Tmin'}>]], dtype=object)

# %%
pd.plotting.scatter_matrix(df,figsize=(20,20))
# Out:
# array([[<AxesSubplot:xlabel='station', ylabel='station'>,
#         <AxesSubplot:xlabel='Date', ylabel='station'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='station'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='station'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='station'>,
#         <AxesSubplot:xlabel='lat', ylabel='station'>,
#         <AxesSubplot:xlabel='lon', ylabel='station'>,
#         <AxesSubplot:xlabel='DEM', ylabel='station'>,
#         <AxesSubplot:xlabel='Slope', ylabel='station'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='station'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='station'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='station'>],
#        [<AxesSubplot:xlabel='station', ylabel='Date'>,
#         <AxesSubplot:xlabel='Date', ylabel='Date'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='Date'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Date'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Date'>,
#         <AxesSubplot:xlabel='lat', ylabel='Date'>,
#         <AxesSubplot:xlabel='lon', ylabel='Date'>,
#         <AxesSubplot:xlabel='DEM', ylabel='Date'>,
#         <AxesSubplot:xlabel='Slope', ylabel='Date'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='Date'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='Date'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='Date'>],
#        [<AxesSubplot:xlabel='station', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='Date', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='lat', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='lon', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='DEM', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='Slope', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='Present_Tmax'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='Present_Tmax'>],
#        [<AxesSubplot:xlabel='station', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='Date', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='lat', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='lon', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='DEM', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='Slope', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='Present_Tmin'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='Present_Tmin'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_RHmin'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_RHmin'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_RHmax'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_RHmax'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_Tmax_lapse'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_Tmax_lapse'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_Tmin_lapse'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_Tmin_lapse'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_WS'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_WS'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_LH'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_LH'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_CC1'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_CC1'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_CC2'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_CC2'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_CC3'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_CC3'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_CC4'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_CC4'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_PPT1'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_PPT1'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_PPT2'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_PPT2'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_PPT3'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_PPT3'>],
#        [<AxesSubplot:xlabel='station', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='Date', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='lat', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='lon', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='DEM', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='Slope', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='LDAPS_PPT4'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='LDAPS_PPT4'>],
#        [<AxesSubplot:xlabel='station', ylabel='lat'>,
#         <AxesSubplot:xlabel='Date', ylabel='lat'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='lat'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='lat'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='lat'>,
#         <AxesSubplot:xlabel='lat', ylabel='lat'>,
#         <AxesSubplot:xlabel='lon', ylabel='lat'>,
#         <AxesSubplot:xlabel='DEM', ylabel='lat'>,
#         <AxesSubplot:xlabel='Slope', ylabel='lat'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='lat'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='lat'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='lat'>],
#        [<AxesSubplot:xlabel='station', ylabel='lon'>,
#         <AxesSubplot:xlabel='Date', ylabel='lon'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='lon'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='lon'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='lon'>,
#         <AxesSubplot:xlabel='lat', ylabel='lon'>,
#         <AxesSubplot:xlabel='lon', ylabel='lon'>,
#         <AxesSubplot:xlabel='DEM', ylabel='lon'>,
#         <AxesSubplot:xlabel='Slope', ylabel='lon'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='lon'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='lon'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='lon'>],
#        [<AxesSubplot:xlabel='station', ylabel='DEM'>,
#         <AxesSubplot:xlabel='Date', ylabel='DEM'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='DEM'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='DEM'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='DEM'>,
#         <AxesSubplot:xlabel='lat', ylabel='DEM'>,
#         <AxesSubplot:xlabel='lon', ylabel='DEM'>,
#         <AxesSubplot:xlabel='DEM', ylabel='DEM'>,
#         <AxesSubplot:xlabel='Slope', ylabel='DEM'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='DEM'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='DEM'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='DEM'>],
#        [<AxesSubplot:xlabel='station', ylabel='Slope'>,
#         <AxesSubplot:xlabel='Date', ylabel='Slope'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='Slope'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Slope'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Slope'>,
#         <AxesSubplot:xlabel='lat', ylabel='Slope'>,
#         <AxesSubplot:xlabel='lon', ylabel='Slope'>,
#         <AxesSubplot:xlabel='DEM', ylabel='Slope'>,
#         <AxesSubplot:xlabel='Slope', ylabel='Slope'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='Slope'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='Slope'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='Slope'>],
#        [<AxesSubplot:xlabel='station', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='Date', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='lat', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='lon', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='DEM', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='Slope', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='Solar radiation'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='Solar radiation'>],
#        [<AxesSubplot:xlabel='station', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='Date', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='lat', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='lon', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='DEM', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='Slope', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='Next_Tmax'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='Next_Tmax'>],
#        [<AxesSubplot:xlabel='station', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='Date', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='Present_Tmax', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='Present_Tmin', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_RHmin', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_RHmax', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_Tmax_lapse', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_Tmin_lapse', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_WS', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_LH', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC1', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC2', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC3', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_CC4', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT1', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT2', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT3', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='LDAPS_PPT4', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='lat', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='lon', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='DEM', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='Slope', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='Solar radiation', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='Next_Tmax', ylabel='Next_Tmin'>,
#         <AxesSubplot:xlabel='Next_Tmin', ylabel='Next_Tmin'>]],
#       dtype=object)

# %%
#dividing the data 
x=df.drop('Next_Tmax',axis=1)
y=df['Next_Tmax']

# %%
#training the data 
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LinearRegression 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.svm import SVC
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import Lasso
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression

# %%
lr=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test,=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i},the training accuracy is = {r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is = {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is = 0.7974897875447478
# At random state 0,the testing accuracy is = 0.8137750393003634
#
#
# At random state 1,the training accuracy is = 0.7998047644339781
# At random state 1,the testing accuracy is = 0.8063722776197598
#
#
# At random state 2,the training accuracy is = 0.8010147466231256
# At random state 2,the testing accuracy is = 0.800943867339684
#
#
# At random state 3,the training accuracy is = 0.7969311216046493
# At random state 3,the testing accuracy is = 0.8171259142210312
#
#
# At random state 4,the training accuracy is = 0.80371417611185
# At random state 4,the testing accuracy is = 0.7897557393411039
#
#
# At random state 5,the training accuracy is = 0.7984033749140238
# At random state 5,the testing accuracy is = 0.811841024514329
#
#
# At random state 6,the training accuracy is = 0.8030096435200873
# At random state 6,the testing accuracy is = 0.7927018838117961
#
#
# At random state 7,the training accuracy is = 0.7999541806860746
# At random state 7,the testing accuracy is = 0.8054327866100851
#
#
# At random state 8,the training accuracy is = 0.8013029855262273
# At random state 8,the testing accuracy is = 0.7999146103455926
#
#
# At random state 9,the training accuracy is = 0.8008459865355081
# At random state 9,the testing accuracy is = 0.8018390377498574
#
#
# At random state 10,the training accuracy is = 0.7999713826576194
# At random state 10,the testing accuracy is = 0.8052775076122647
#
#
# At random state 11,the training accuracy is = 0.8014571880840136
# At random state 11,the testing accuracy is = 0.7992243899346797
#
#
# At random state 12,the training accuracy is = 0.8030893225933339
# At random state 12,the testing accuracy is = 0.7928624262554118
#
#
# At random state 13,the training accuracy is = 0.8022873621770601
# At random state 13,the testing accuracy is = 0.7958427278098792
#
#
# At random state 14,the training accuracy is = 0.7987093932521673
# At random state 14,the testing accuracy is = 0.8100488183773485
#
#
# At random state 15,the training accuracy is = 0.8067554045696632
# At random state 15,the testing accuracy is = 0.7759158362464185
#
#
# At random state 16,the training accuracy is = 0.7989007590373116
# At random state 16,the testing accuracy is = 0.8094058208876485
#
#
# At random state 17,the training accuracy is = 0.8005167689669561
# At random state 17,the testing accuracy is = 0.8033775627195489
#
#
# At random state 18,the training accuracy is = 0.8012683015361073
# At random state 18,the testing accuracy is = 0.7996776189139551
#
#
# At random state 19,the training accuracy is = 0.8037354360189142
# At random state 19,the testing accuracy is = 0.7899863482437262
#
#
# At random state 20,the training accuracy is = 0.7999405781088071
# At random state 20,the testing accuracy is = 0.8042038127447058
#
#
# At random state 21,the training accuracy is = 0.7985247639995631
# At random state 21,the testing accuracy is = 0.8107976706869765
#
#
# At random state 22,the training accuracy is = 0.7997581999295785
# At random state 22,the testing accuracy is = 0.8057085853788516
#
#
# At random state 23,the training accuracy is = 0.80169921579794
# At random state 23,the testing accuracy is = 0.7977230239699624
#
#
# At random state 24,the training accuracy is = 0.7996653158284862
# At random state 24,the testing accuracy is = 0.8068006740698354
#
#
# At random state 25,the training accuracy is = 0.8005088252141656
# At random state 25,the testing accuracy is = 0.8030081581158072
#
#
# At random state 26,the training accuracy is = 0.8040520604265573
# At random state 26,the testing accuracy is = 0.7895719081799909
#
#
# At random state 27,the training accuracy is = 0.8010747796317628
# At random state 27,the testing accuracy is = 0.8006148966472024
#
#
# At random state 28,the training accuracy is = 0.7992848852276646
# At random state 28,the testing accuracy is = 0.8076893156206726
#
#
# At random state 29,the training accuracy is = 0.7994995778965168
# At random state 29,the testing accuracy is = 0.806863082372054
#
#
# At random state 30,the training accuracy is = 0.7959862363560142
# At random state 30,the testing accuracy is = 0.8203830600757542
#
#
# At random state 31,the training accuracy is = 0.803895531482661
# At random state 31,the testing accuracy is = 0.7889768993868593
#
#
# At random state 32,the training accuracy is = 0.8018960402285094
# At random state 32,the testing accuracy is = 0.7970906817033688
#
#
# At random state 33,the training accuracy is = 0.8034043326624668
# At random state 33,the testing accuracy is = 0.7913120569753027
#
#
# At random state 34,the training accuracy is = 0.7999197175584184
# At random state 34,the testing accuracy is = 0.8052075180081104
#
#
# At random state 35,the training accuracy is = 0.8001934166753024
# At random state 35,the testing accuracy is = 0.8046679317433865
#
#
# At random state 36,the training accuracy is = 0.805096207452842
# At random state 36,the testing accuracy is = 0.7843414422692699
#
#
# At random state 37,the training accuracy is = 0.803110718213944
# At random state 37,the testing accuracy is = 0.7926864446388917
#
#
# At random state 38,the training accuracy is = 0.8017764639025786
# At random state 38,the testing accuracy is = 0.7974374405382525
#
#
# At random state 39,the training accuracy is = 0.8010907921218413
# At random state 39,the testing accuracy is = 0.8012029243249326
#
#
# At random state 40,the training accuracy is = 0.8066574642888256
# At random state 40,the testing accuracy is = 0.7777647001737859
#
#
# At random state 41,the training accuracy is = 0.8004293132567059
# At random state 41,the testing accuracy is = 0.8032274642113983
#
#
# At random state 42,the training accuracy is = 0.8051623554377866
# At random state 42,the testing accuracy is = 0.7834563682275854
#
#
# At random state 43,the training accuracy is = 0.7978049778190686
# At random state 43,the testing accuracy is = 0.8139460913173557
#
#
# At random state 44,the training accuracy is = 0.8062149205541557
# At random state 44,the testing accuracy is = 0.7788914090365019
#
#
# At random state 45,the training accuracy is = 0.8039368799050952
# At random state 45,the testing accuracy is = 0.7899209504457799
#
#
# At random state 46,the training accuracy is = 0.801266489483035
# At random state 46,the testing accuracy is = 0.8002699438651324
#
#
# At random state 47,the training accuracy is = 0.8020763775819415
# At random state 47,the testing accuracy is = 0.7964149772385054
#
#
# At random state 48,the training accuracy is = 0.7990725606966786
# At random state 48,the testing accuracy is = 0.808246834303539
#
#
# At random state 49,the training accuracy is = 0.8033281514712131
# At random state 49,the testing accuracy is = 0.7917672673491941
#
#
# At random state 50,the training accuracy is = 0.7988622569938835
# At random state 50,the testing accuracy is = 0.809029542145869
#
#
# At random state 51,the training accuracy is = 0.79950836627615
# At random state 51,the testing accuracy is = 0.8072402551969293
#
#
# At random state 52,the training accuracy is = 0.80175025549395
# At random state 52,the testing accuracy is = 0.7976926835793537
#
#
# At random state 53,the training accuracy is = 0.8034795004120278
# At random state 53,the testing accuracy is = 0.7915728447508805
#
#
# At random state 54,the training accuracy is = 0.8010348295782969
# At random state 54,the testing accuracy is = 0.8010268726896798
#
#
# At random state 55,the training accuracy is = 0.7977870003572864
# At random state 55,the testing accuracy is = 0.8133066454018574
#
#
# At random state 56,the training accuracy is = 0.7981179338996132
# At random state 56,the testing accuracy is = 0.8122682051068151
#
#
# At random state 57,the training accuracy is = 0.8016614465929722
# At random state 57,the testing accuracy is = 0.7986452177643462
#
#
# At random state 58,the training accuracy is = 0.799938804273441
# At random state 58,the testing accuracy is = 0.8050138969564689
#
#
# At random state 59,the training accuracy is = 0.8009514427497896
# At random state 59,the testing accuracy is = 0.8012773567497473
#
#
# At random state 60,the training accuracy is = 0.7983749011898489
# At random state 60,the testing accuracy is = 0.8110688577571414
#
#
# At random state 61,the training accuracy is = 0.7983016563765675
# At random state 61,the testing accuracy is = 0.8116061046857299
#
#
# At random state 62,the training accuracy is = 0.7999131373013386
# At random state 62,the testing accuracy is = 0.805392914398932
#
#
# At random state 63,the training accuracy is = 0.8017035542371724
# At random state 63,the testing accuracy is = 0.798717272200713
#
#
# At random state 64,the training accuracy is = 0.8042710419593199
# At random state 64,the testing accuracy is = 0.7872973444185944
#
#
# At random state 65,the training accuracy is = 0.8046250082745046
# At random state 65,the testing accuracy is = 0.7871900245251987
#
#
# At random state 66,the training accuracy is = 0.8043622793479717
# At random state 66,the testing accuracy is = 0.7877664766212136
#
#
# At random state 67,the training accuracy is = 0.8060365840077932
# At random state 67,the testing accuracy is = 0.7800003663414716
#
#
# At random state 68,the training accuracy is = 0.801416651208724
# At random state 68,the testing accuracy is = 0.7995293269896245
#
#
# At random state 69,the training accuracy is = 0.7996221007500758
# At random state 69,the testing accuracy is = 0.8063321471701266
#
#
# At random state 70,the training accuracy is = 0.7979762465476714
# At random state 70,the testing accuracy is = 0.8127695908502
#
#
# At random state 71,the training accuracy is = 0.7967860855435361
# At random state 71,the testing accuracy is = 0.8181713665931751
#
#
# At random state 72,the training accuracy is = 0.8036834364947589
# At random state 72,the testing accuracy is = 0.7899151935933604
#
#
# At random state 73,the training accuracy is = 0.8003297716779595
# At random state 73,the testing accuracy is = 0.803975310357084
#
#
# At random state 74,the training accuracy is = 0.8039017723771099
# At random state 74,the testing accuracy is = 0.7894001089597972
#
#
# At random state 75,the training accuracy is = 0.8008873490186088
# At random state 75,the testing accuracy is = 0.8014679880980724
#
#
# At random state 76,the training accuracy is = 0.8055077295094397
# At random state 76,the testing accuracy is = 0.7824824080225431
#
#
# At random state 77,the training accuracy is = 0.8043152980208228
# At random state 77,the testing accuracy is = 0.7870763811963799
#
#
# At random state 78,the training accuracy is = 0.8033058593886011
# At random state 78,the testing accuracy is = 0.791431112281765
#
#
# At random state 79,the training accuracy is = 0.7974650100964927
# At random state 79,the testing accuracy is = 0.8150342080540858
#
#
# At random state 80,the training accuracy is = 0.8007535635907179
# At random state 80,the testing accuracy is = 0.8019671374067402
#
#
# At random state 81,the training accuracy is = 0.7993775211660143
# At random state 81,the testing accuracy is = 0.8075750394727039
#
#
# At random state 82,the training accuracy is = 0.8003685158828276
# At random state 82,the testing accuracy is = 0.8042412976316937
#
#
# At random state 83,the training accuracy is = 0.8031862888094953
# At random state 83,the testing accuracy is = 0.7920156104900955
#
#
# At random state 84,the training accuracy is = 0.7994194563929147
# At random state 84,the testing accuracy is = 0.8072274323005224
#
#
# At random state 85,the training accuracy is = 0.7984841742707625
# At random state 85,the testing accuracy is = 0.8111856084589397
#
#
# At random state 86,the training accuracy is = 0.8005218257021649
# At random state 86,the testing accuracy is = 0.8029625662185966
#
#
# At random state 87,the training accuracy is = 0.8026999413588632
# At random state 87,the testing accuracy is = 0.7940200650070521
#
#
# At random state 88,the training accuracy is = 0.8036268312079391
# At random state 88,the testing accuracy is = 0.7902252255870226
#
#
# At random state 89,the training accuracy is = 0.7985026836348246
# At random state 89,the testing accuracy is = 0.8113684833222226
#
#
# At random state 90,the training accuracy is = 0.7998562942925544
# At random state 90,the testing accuracy is = 0.8052938544838649
#
#
# At random state 91,the training accuracy is = 0.8043920624046003
# At random state 91,the testing accuracy is = 0.786603236974496
#
#
# At random state 92,the training accuracy is = 0.7992673974561091
# At random state 92,the testing accuracy is = 0.807505582511084
#
#
# At random state 93,the training accuracy is = 0.802541268280281
# At random state 93,the testing accuracy is = 0.7950256459098227
#
#
# At random state 94,the training accuracy is = 0.8027796173742556
# At random state 94,the testing accuracy is = 0.7932152835540016
#
#
# At random state 95,the training accuracy is = 0.7996625046072565
# At random state 95,the testing accuracy is = 0.8061861023237017
#
#
# At random state 96,the training accuracy is = 0.8009311345735732
# At random state 96,the testing accuracy is = 0.8016803991965284
#
#
# At random state 97,the training accuracy is = 0.8006376044504526
# At random state 97,the testing accuracy is = 0.8026603697572785
#
#
# At random state 98,the training accuracy is = 0.8040783112428486
# At random state 98,the testing accuracy is = 0.7875976707439167
#
#
# At random state 99,the training accuracy is = 0.7989570359552666
# At random state 99,the testing accuracy is = 0.8086413042008617

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=49)

# %%
pred_test=lr.predict(x_test)

# %%
pred_train=lr.predict(x_train)

# %%
print(r2_score(y_test,pred_test)*100)
# Out:
# 79.42755942638108

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
lr.fit(x_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
pred_test=lr.predict(x_test)
pred_test
# Out:
# array([32.7509454 , 27.44292757, 32.74199303, ..., 29.44754825,
#        25.10300033, 29.34808926])

# %%
pred_train=lr.predict(x_train)
pred_train
# Out:
# array([32.80491789, 31.66381523, 26.72876863, ..., 30.24842055,
#        33.59477043, 27.79947224])

# %%
lr_accuracy=round(lr.score(x_train,y_train)*100)
lr_accuracy
# Out:
# 80

# %%
from sklearn.tree import DecisionTreeRegressor
tree=DecisionTreeRegressor(max_depth=15, min_samples_leaf=2)
tree.fit(x_train,y_train)
tree_pred=tree.predict(x_test)
tree_pred
# Out:
# array([32.32272727, 28.9       , 31.38461538, ..., 30.02941176,
#        26.66666667, 30.2       ])

# %%
tree_accuracy=round(tree.score(x_train,y_train)*100)
tree_accuracy
# Out:
# 98

# %%
from sklearn.ensemble import RandomForestRegressor 
rf=RandomForestRegressor(n_estimators=400,max_depth=6,min_samples_leaf=2,n_jobs=4)
rf.fit(x_train,y_train)
rf.pred=rf.predict(x_test)

# %%
rf_accuracy=round(rf.score(x_train,y_train)*100)
rf_accuracy
# Out:
# 85

# %%
import xgboost
from xgboost import XGBRegressor

model=XGBRegressor(n_estimators=100,learning_rate=0.05)
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([31.765192, 28.799892, 32.643364, ..., 29.116983, 25.431475,
#        29.531788], dtype=float32)

# %%
model.score(x_train,y_train)*100
# Out:
# 93.41358640072058

# %%
model_accuracy=round(model.score(x_train,y_train)*100)
model_accuracy
# Out:
# 93

# %%
#Cross validation  for desisiontree
scr=cross_val_score(tree,x,y,cv=5)
scr.mean()
print("Cross validation score of DecisionTreeRegression:",scr.mean())
# Out:
# Cross validation score of DecisionTreeRegression: 0.51768189650321

# %%
#Cross validation  for xgboost
scr=cross_val_score(model,x,y,cv=5)
scr.mean()
print("Cross validation score of Xgboost:",scr.mean())
# Out:
# Cross validation score of Xgboost: 0.7330280112810014

# %% [markdown]
# The Exploratory Data Analysis was well done and the training of the data was smoothly completed. W ehave been able to achive a good model for the first target variable. Now we save the  model.

# %%
#saving the model
import pickle 
filename='churn.pkl'
pickle.dump(tree,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('churn.pkl','rb'))
result=loaded_model.score(x_test,y_test)*100
result
# Out:
# 81.84606466168559

# %%
#creatig a new df
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_train[:]],index=["Predicted","Original"])

# %%
conclusion
# Out:
#                 0          1          2          3          4          5     \
# Predicted  32.322727  28.900000  31.384615  31.250000  31.550000  23.400000
# Original   32.804918  31.663815  26.728769  31.088068  32.629083  32.144795
#
#                 6          7          8          9     ...       6060  \
# Predicted  25.888571  28.700000  34.100000  31.400000  ...        NaN
# Original   29.559672  25.607489  30.725471  30.354197  ...  33.781215
#
#                 6061       6062      6063       6064       6065       6066  \
# Predicted        NaN        NaN       NaN        NaN        NaN        NaN
# Original   29.512095  25.589249  31.30228  30.863809  25.940027  29.139452
#
#                 6067      6068       6069
# Predicted        NaN       NaN        NaN
# Original   30.248421  33.59477  27.799472
#
# [2 rows x 6070 columns]

# %% [markdown]
# Moving to the next target variable

# %%
#dividing the data 
x=df.drop('Next_Tmin',axis=1)
y=df['Next_Tmin']

# %%
lr=LinearRegression()

for i in range(0,100):
    x_train,x_test,y_train,y_test,=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"At random state {i},the training accuracy is = {r2_score(y_train,pred_train)}")
    print(f"At random state {i},the testing accuracy is = {r2_score(y_test,pred_test)}")
    print("\n")
# Out:
# At random state 0,the training accuracy is = 0.850758321105587
# At random state 0,the testing accuracy is = 0.8526464131347091
#
#
# At random state 1,the training accuracy is = 0.8523240523569648
# At random state 1,the testing accuracy is = 0.8454347854175598
#
#
# At random state 2,the training accuracy is = 0.8501609888451299
# At random state 2,the testing accuracy is = 0.8542110285736274
#
#
# At random state 3,the training accuracy is = 0.8517619434055109
# At random state 3,the testing accuracy is = 0.8487904936486743
#
#
# At random state 4,the training accuracy is = 0.8497887528320689
# At random state 4,the testing accuracy is = 0.8559608094887899
#
#
# At random state 5,the training accuracy is = 0.8504020590046403
# At random state 5,the testing accuracy is = 0.8534615792453758
#
#
# At random state 6,the training accuracy is = 0.8540702636724339
# At random state 6,the testing accuracy is = 0.838715281918968
#
#
# At random state 7,the training accuracy is = 0.8491786782844355
# At random state 7,the testing accuracy is = 0.8586037154806041
#
#
# At random state 8,the training accuracy is = 0.8508452678267934
# At random state 8,the testing accuracy is = 0.8523510242650449
#
#
# At random state 9,the training accuracy is = 0.8518707186892357
# At random state 9,the testing accuracy is = 0.8473771560022549
#
#
# At random state 10,the training accuracy is = 0.8496532751051362
# At random state 10,the testing accuracy is = 0.8565847158105309
#
#
# At random state 11,the training accuracy is = 0.8515243194591391
# At random state 11,the testing accuracy is = 0.8495053253342912
#
#
# At random state 12,the training accuracy is = 0.8533538847442462
# At random state 12,the testing accuracy is = 0.8416508264015612
#
#
# At random state 13,the training accuracy is = 0.8536226184899663
# At random state 13,the testing accuracy is = 0.8400151680417338
#
#
# At random state 14,the training accuracy is = 0.8515834678341712
# At random state 14,the testing accuracy is = 0.8489389429004597
#
#
# At random state 15,the training accuracy is = 0.850683002098143
# At random state 15,the testing accuracy is = 0.8527746903858986
#
#
# At random state 16,the training accuracy is = 0.8532203187334283
# At random state 16,the testing accuracy is = 0.8421472956007768
#
#
# At random state 17,the training accuracy is = 0.850567236548035
# At random state 17,the testing accuracy is = 0.8525034077206647
#
#
# At random state 18,the training accuracy is = 0.8507503961718592
# At random state 18,the testing accuracy is = 0.8522639215808001
#
#
# At random state 19,the training accuracy is = 0.852834158874235
# At random state 19,the testing accuracy is = 0.844500419054906
#
#
# At random state 20,the training accuracy is = 0.8542737696861393
# At random state 20,the testing accuracy is = 0.8363915352031923
#
#
# At random state 21,the training accuracy is = 0.8511221719005325
# At random state 21,the testing accuracy is = 0.8510992955640432
#
#
# At random state 22,the training accuracy is = 0.8498178671383
# At random state 22,the testing accuracy is = 0.8557456360498894
#
#
# At random state 23,the training accuracy is = 0.8523303920757962
# At random state 23,the testing accuracy is = 0.846014969097679
#
#
# At random state 24,the training accuracy is = 0.8497113757474469
# At random state 24,the testing accuracy is = 0.8563788690720369
#
#
# At random state 25,the training accuracy is = 0.8498331397274469
# At random state 25,the testing accuracy is = 0.8554039966184854
#
#
# At random state 26,the training accuracy is = 0.8490976586527627
# At random state 26,the testing accuracy is = 0.8592113465369595
#
#
# At random state 27,the training accuracy is = 0.8513350673396992
# At random state 27,the testing accuracy is = 0.8501332789569995
#
#
# At random state 28,the training accuracy is = 0.8513977659085834
# At random state 28,the testing accuracy is = 0.8498168834426689
#
#
# At random state 29,the training accuracy is = 0.8489452346499076
# At random state 29,the testing accuracy is = 0.859713834209854
#
#
# At random state 30,the training accuracy is = 0.8520282772091365
# At random state 30,the testing accuracy is = 0.8472002450839298
#
#
# At random state 31,the training accuracy is = 0.8515749077910417
# At random state 31,the testing accuracy is = 0.8493929982058271
#
#
# At random state 32,the training accuracy is = 0.8525309001819945
# At random state 32,the testing accuracy is = 0.845412054571233
#
#
# At random state 33,the training accuracy is = 0.8505398080574225
# At random state 33,the testing accuracy is = 0.8533680756457603
#
#
# At random state 34,the training accuracy is = 0.8512965613798957
# At random state 34,the testing accuracy is = 0.8504106949806476
#
#
# At random state 35,the training accuracy is = 0.8505373376809375
# At random state 35,the testing accuracy is = 0.8536404375727036
#
#
# At random state 36,the training accuracy is = 0.8518103785622633
# At random state 36,the testing accuracy is = 0.8480744116731633
#
#
# At random state 37,the training accuracy is = 0.850386924762566
# At random state 37,the testing accuracy is = 0.853518028577084
#
#
# At random state 38,the training accuracy is = 0.8515923290205997
# At random state 38,the testing accuracy is = 0.8493441989519561
#
#
# At random state 39,the training accuracy is = 0.8518148655093976
# At random state 39,the testing accuracy is = 0.8481500920471715
#
#
# At random state 40,the training accuracy is = 0.8515750160351376
# At random state 40,the testing accuracy is = 0.8493081888265972
#
#
# At random state 41,the training accuracy is = 0.8523992326543175
# At random state 41,the testing accuracy is = 0.8456063457834095
#
#
# At random state 42,the training accuracy is = 0.8531839656989925
# At random state 42,the testing accuracy is = 0.8425984777940843
#
#
# At random state 43,the training accuracy is = 0.8495014007859973
# At random state 43,the testing accuracy is = 0.8574224521481025
#
#
# At random state 44,the training accuracy is = 0.8548466097015615
# At random state 44,the testing accuracy is = 0.8360530339633995
#
#
# At random state 45,the training accuracy is = 0.8500547081853722
# At random state 45,the testing accuracy is = 0.8551530905089264
#
#
# At random state 46,the training accuracy is = 0.8524789248308364
# At random state 46,the testing accuracy is = 0.8459507810521383
#
#
# At random state 47,the training accuracy is = 0.8507395167845571
# At random state 47,the testing accuracy is = 0.8523188879677546
#
#
# At random state 48,the training accuracy is = 0.8495251103431412
# At random state 48,the testing accuracy is = 0.8572653353980456
#
#
# At random state 49,the training accuracy is = 0.8499599145033084
# At random state 49,the testing accuracy is = 0.8551421412196981
#
#
# At random state 50,the training accuracy is = 0.8518183577764443
# At random state 50,the testing accuracy is = 0.8481604811366525
#
#
# At random state 51,the training accuracy is = 0.849118611329547
# At random state 51,the testing accuracy is = 0.8586017856729297
#
#
# At random state 52,the training accuracy is = 0.8508747168641088
# At random state 52,the testing accuracy is = 0.8520691483946653
#
#
# At random state 53,the training accuracy is = 0.8514948009279841
# At random state 53,the testing accuracy is = 0.8495675967078526
#
#
# At random state 54,the training accuracy is = 0.850394917752585
# At random state 54,the testing accuracy is = 0.8540014266224586
#
#
# At random state 55,the training accuracy is = 0.850233012088451
# At random state 55,the testing accuracy is = 0.8544627242094518
#
#
# At random state 56,the training accuracy is = 0.8508060072339059
# At random state 56,the testing accuracy is = 0.8521729843262944
#
#
# At random state 57,the training accuracy is = 0.8540525564557794
# At random state 57,the testing accuracy is = 0.8400149630153501
#
#
# At random state 58,the training accuracy is = 0.8509470500404954
# At random state 58,the testing accuracy is = 0.8514944212925668
#
#
# At random state 59,the training accuracy is = 0.8536257275184593
# At random state 59,the testing accuracy is = 0.8405141398320468
#
#
# At random state 60,the training accuracy is = 0.8466004995621677
# At random state 60,the testing accuracy is = 0.868056958268933
#
#
# At random state 61,the training accuracy is = 0.8524523553247223
# At random state 61,the testing accuracy is = 0.8460028966568152
#
#
# At random state 62,the training accuracy is = 0.8481591888445525
# At random state 62,the testing accuracy is = 0.8621562639929577
#
#
# At random state 63,the training accuracy is = 0.8527064656948686
# At random state 63,the testing accuracy is = 0.8448632589715571
#
#
# At random state 64,the training accuracy is = 0.8495069178134598
# At random state 64,the testing accuracy is = 0.8573263782990547
#
#
# At random state 65,the training accuracy is = 0.8538527234028179
# At random state 65,the testing accuracy is = 0.8399225444975026
#
#
# At random state 66,the training accuracy is = 0.8519003265154195
# At random state 66,the testing accuracy is = 0.8473070845232809
#
#
# At random state 67,the training accuracy is = 0.8526809365675967
# At random state 67,the testing accuracy is = 0.8448369880034257
#
#
# At random state 68,the training accuracy is = 0.8474531698197418
# At random state 68,the testing accuracy is = 0.864723466661835
#
#
# At random state 69,the training accuracy is = 0.8538402418496605
# At random state 69,the testing accuracy is = 0.8399791565038038
#
#
# At random state 70,the training accuracy is = 0.849399514030345
# At random state 70,the testing accuracy is = 0.8581644589821017
#
#
# At random state 71,the training accuracy is = 0.8491844548240468
# At random state 71,the testing accuracy is = 0.8586618544050783
#
#
# At random state 72,the training accuracy is = 0.8521093104550892
# At random state 72,the testing accuracy is = 0.8462700982830443
#
#
# At random state 73,the training accuracy is = 0.8550848995441804
# At random state 73,the testing accuracy is = 0.834233399482984
#
#
# At random state 74,the training accuracy is = 0.8517160754240981
# At random state 74,the testing accuracy is = 0.848463787067232
#
#
# At random state 75,the training accuracy is = 0.8501211512752259
# At random state 75,the testing accuracy is = 0.8549818253333654
#
#
# At random state 76,the training accuracy is = 0.8526268329685425
# At random state 76,the testing accuracy is = 0.8441989808003334
#
#
# At random state 77,the training accuracy is = 0.8517507085522692
# At random state 77,the testing accuracy is = 0.8484585257528715
#
#
# At random state 78,the training accuracy is = 0.8512109794393639
# At random state 78,the testing accuracy is = 0.8503632512442529
#
#
# At random state 79,the training accuracy is = 0.851314597527503
# At random state 79,the testing accuracy is = 0.85006340537255
#
#
# At random state 80,the training accuracy is = 0.8529073833883454
# At random state 80,the testing accuracy is = 0.844113479451051
#
#
# At random state 81,the training accuracy is = 0.8490530348645993
# At random state 81,the testing accuracy is = 0.8592016806371778
#
#
# At random state 82,the training accuracy is = 0.852861662885539
# At random state 82,the testing accuracy is = 0.8440652110770659
#
#
# At random state 83,the training accuracy is = 0.8519975618385032
# At random state 83,the testing accuracy is = 0.8475297361990779
#
#
# At random state 84,the training accuracy is = 0.8492903616600912
# At random state 84,the testing accuracy is = 0.8578413924681642
#
#
# At random state 85,the training accuracy is = 0.8493021130023621
# At random state 85,the testing accuracy is = 0.8580124317564377
#
#
# At random state 86,the training accuracy is = 0.8520180126996989
# At random state 86,the testing accuracy is = 0.8473274403536286
#
#
# At random state 87,the training accuracy is = 0.8518017293253336
# At random state 87,the testing accuracy is = 0.8478772318046708
#
#
# At random state 88,the training accuracy is = 0.849601076966128
# At random state 88,the testing accuracy is = 0.8573466571805665
#
#
# At random state 89,the training accuracy is = 0.8524905792501423
# At random state 89,the testing accuracy is = 0.8454872140337091
#
#
# At random state 90,the training accuracy is = 0.8492386187174533
# At random state 90,the testing accuracy is = 0.8583783017292786
#
#
# At random state 91,the training accuracy is = 0.8487742900991118
# At random state 91,the testing accuracy is = 0.8608396925492754
#
#
# At random state 92,the training accuracy is = 0.8491440498201548
# At random state 92,the testing accuracy is = 0.858676666242195
#
#
# At random state 93,the training accuracy is = 0.8534587661501322
# At random state 93,the testing accuracy is = 0.8410658383834252
#
#
# At random state 94,the training accuracy is = 0.8518935817556151
# At random state 94,the testing accuracy is = 0.8481600075345854
#
#
# At random state 95,the training accuracy is = 0.8517339570186345
# At random state 95,the testing accuracy is = 0.8483828726326162
#
#
# At random state 96,the training accuracy is = 0.8497495518827278
# At random state 96,the testing accuracy is = 0.855976876903749
#
#
# At random state 97,the training accuracy is = 0.8524900883391575
# At random state 97,the testing accuracy is = 0.8448285538076936
#
#
# At random state 98,the training accuracy is = 0.8523428052548264
# At random state 98,the testing accuracy is = 0.8463887687937068
#
#
# At random state 99,the training accuracy is = 0.8506785672553272
# At random state 99,the testing accuracy is = 0.8529052176555918

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=49)

# %%
pred_test=lr.predict(x_test)

# %%
pred_train=lr.predict(x_train)

# %%
print(r2_score(y_test,pred_test)*100)
# Out:
# 85.54159960838915

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression(normalize=True)
lr.fit(x_train,y_train)
# Out:
# LinearRegression(normalize=True)

# %%
pred_test=lr.predict(x_test)
pred_test
# Out:
# array([22.7161495 , 24.40555305, 25.48575799, ..., 19.37944003,
#        21.17826368, 18.85258527])

# %%
pred_train=lr.predict(x_train)
pred_train
# Out:
# array([22.47443421, 23.61876841, 20.94678623, ..., 19.90354849,
#        26.40301581, 23.25831686])

# %%
lr_accuracy=round(lr.score(x_train,y_train)*100)
lr_accuracy
# Out:
# 85

# %%
from sklearn.tree import DecisionTreeRegressor
tree=DecisionTreeRegressor(max_depth=15, min_samples_leaf=2)
tree.fit(x_train,y_train)
tree_pred=tree.predict(x_test)
tree_pred
# Out:
# array([23.66      , 22.35      , 25.945     , ..., 17.85      ,
#        21.8       , 19.26666667])

# %%
tree_accuracy=round(tree.score(x_train,y_train)*100)
tree_accuracy
# Out:
# 99

# %%
from sklearn.ensemble import RandomForestRegressor 
rf=RandomForestRegressor(n_estimators=400,max_depth=6,min_samples_leaf=2,n_jobs=4)
rf.fit(x_train,y_train)
rf.pred=rf.predict(x_test)

# %%
rf_accuracy=round(rf.score(x_train,y_train)*100)
rf_accuracy
# Out:
# 88

# %%
import xgboost
from xgboost import XGBRegressor

model=XGBRegressor(n_estimators=100,learning_rate=0.05)
model.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.05, max_delta_step=0,
#              max_depth=6, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimators=100, n_jobs=8,
#              num_parallel_tree=1, predictor='auto', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([22.363087, 24.304604, 25.782072, ..., 19.418821, 21.169495,
#        19.237326], dtype=float32)

# %%
model.score(x_train,y_train)*100
# Out:
# 94.77036056400016

# %%
model_accuracy=round(model.score(x_train,y_train)*100)
model_accuracy
# Out:
# 95

# %%
#Cross validation  for desisiontree
scr=cross_val_score(tree,x,y,cv=5)
scr.mean()
print("Cross validation score of DecisionTreeRegression:",scr.mean())
# Out:
# Cross validation score of DecisionTreeRegression: 0.605368086190196

# %%
#Cross validation  for xgboost
scr=cross_val_score(model,x,y,cv=5)
scr.mean()
print("Cross validation score of Xgboost:",scr.mean())
# Out:
# Cross validation score of Xgboost: 0.8015025162739284

# %% [markdown]
# Decision Tree gave the best model hemce we'll be sacing that model.

# %%
#saving the model
import pickle 
filename='churn.pkl'
pickle.dump(tree,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('churn.pkl','rb'))
result=loaded_model.score(x_test,y_test)*100
result
# Out:
# 81.0473410040456

# %%
#creatig a new df
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],pred_train[:]],index=["Predicted","Original"])

# %%
conclusion
# Out:
#                 0          1          2         3          4          5     \
# Predicted  23.660000  22.350000  25.945000  22.55000  23.250000  20.000000
# Original   22.474434  23.618768  20.946786  24.45156  21.231261  23.930392
#
#                 6         7          8          9     ...       6060  \
# Predicted  22.400000  24.70000  26.550000  20.750000  ...        NaN
# Original   23.422453  20.26514  20.040936  19.003741  ...  23.722944
#
#                 6061       6062       6063       6064      6065       6066  \
# Predicted        NaN        NaN        NaN        NaN       NaN        NaN
# Original   22.951375  20.722697  25.089475  25.810666  19.64745  21.756172
#
#                 6067       6068       6069
# Predicted        NaN        NaN        NaN
# Original   19.903548  26.403016  23.258317
#
# [2 rows x 6070 columns]

# %% [markdown]
# We have successfully built two models for both of the target variables.
